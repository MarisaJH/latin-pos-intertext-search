# %%
from transformers import AutoTokenizer, AutoModel
import pandas as pd
import glob
from natsort import natsorted
from bert_embeddings import load_data
import re
import Levenshtein
import numpy as np
from itertools import product, combinations

# %%
DEBUG = True
TEXTS_FOLDER = "../data/texts/process"
EMBEDDINGS_FOLDER = "../data/bert_embeddings"

files = natsorted(glob.glob(f'{TEXTS_FOLDER}/*.tess'))
files_embeddings = natsorted(glob.glob(f'{EMBEDDINGS_FOLDER}/*.pos.pkl'))
MODEL = 'bowphs/LaBerta'
lemmatize = False

# %%
comps = pd.read_csv('../data/datasets/comps_paper.csv', index_col=0)

# %%
vf_file = EMBEDDINGS_FOLDER + "/valerius_flaccus.argonautica.part.1.tess.pos.pkl"
vf_data = load_data(vf_file)

# %%
def sort_data(data: dict):
    # reorder vf_data so that the lines are in order
    # sort by 'references' key
    new_references = sorted(data['references'], key=lambda x: int(x.split('.')[-1]))

    # reorder vf_data
    old_ref_to_idx = {ref: i for i, ref in enumerate(data['references'])}
    #new_data = deepcopy(data)
    #for i, ref in enumerate(new_references):
    #    new_data['references'][i] = ref
    #    new_data['embeddings'][i] = data['embeddings'][old_ref_to_idx[ref]]
    #    new_data['sentences'][i] = data['sentences'][old_ref_to_idx[ref]]
    #    new_data['subword_tokens'][i] = data['subword_tokens'][old_ref_to_idx[ref]]
    #    new_data['word_tokens'][i] = data['word_tokens'][old_ref_to_idx[ref]]
    #    new_data['word_to_tokens_maps'][i] = data['word_to_tokens_maps'][old_ref_to_idx[ref]]

    # ref -> {key: value}
    new_data = {}
    for i, ref in enumerate(new_references):
        new_data[ref] = {key: data[key][old_ref_to_idx[ref]] for key in data.keys()}
    return new_data

# %%
new_vf_data = sort_data(vf_data)

# %%
class JVReplacer:  # pylint: disable=too-few-public-methods
    """Replace J/V with I/U.
    Latin alphabet does not distinguish between J/j and I/i and V/v and U/u;
    Yet, many texts bear the influence of later editors and the predilections of other languages.

    In practical terms, the JV substitution is recommended on all Latin text preprocessing; it
    helps to collapse the search space.

    >>> replacer = JVReplacer()
    >>> replacer.replace("Julius Caesar")
    'Iulius Caesar'

    >>> replacer.replace("In vino veritas.")
    'In uino ueritas.'

    """

    def __init__(self):
        """Initialization for JVReplacer, reads replacement pattern tuple."""
        patterns = [(r"j", "i"), (r"v", "u"), (r"J", "I"), (r"V", "U")]
        self.patterns = [(re.compile(regex), repl) for (regex, repl) in patterns]

    def replace(self, text):
        """Do j/v replacement"""
        for pattern, repl in self.patterns:
            text = re.subn(pattern, repl, text)[0]
        return text

# %%
REPLACER = JVReplacer()

# %%
def clean_word(word: str):
    word = word.lower()
    word = REPLACER.replace(word)

    # special cases
    #if word in ['fatidicamque', 'mediosque']:
    #    word = word[:-3]
    return word

# %%
def search_for_word(word: str, word_tokens: list[list[str]]):
    strip_que = not(word.endswith('que') and len(word) > 3)
    strip_ne = not(word.endswith('ne') and len(word) > 2)
    
    for i, line in enumerate(word_tokens):
        for j, w in enumerate(line):
            if strip_que and w.endswith('que') and len(w) > 3:
                stripped_word = w[:-3]
                if stripped_word == word:
                    return i, j
            elif strip_ne and w.endswith('ne') and len(w) > 2:
                stripped_word = w[:-2]
                if stripped_word == word:
                    return i, j
            else:
                if w == word:
                    return i, j
    return -1, -1

# %%
def find_closest_word(word: str, alt_phrase: list[str]):
    # find the word in alt_phrase that has the smallest edit distance to word
    min_dist = float('inf')
    closest_word = None
    for alt_word in alt_phrase:
        dist = Levenshtein.distance(word, alt_word)
        if dist < min_dist:
            min_dist = dist
            closest_word = alt_word
    return closest_word, min_dist

# %%
def get_line_keys(data: dict, line_pos: tuple[int, int]):
    first_key = ''
    for key in data:
        first_key = key
        break

    *key_prefix, _ = first_key.split('.')
    key_prefix = '.'.join(key_prefix)

    start, end = line_pos
    keys = [f'{key_prefix}.{i}' for i in range(start, end+1)]
    # remove any keys that don't exist
    keys = [key for key in keys if key in data]
    return keys

# %%
def get_bigram_embeddings(bigram: tuple[str, str], alt_phrase: list[str], data: dict, line_pos: tuple[int, int]):
    ''' 
    bigram: tuple of two strings, the bigram to find in the text
    data: dictionary of embeddings for the Tesseract file
    line_pos: tuple of two ints, the start and end indices of the lines to search
    interval: int, the interval between the the words in the bigram
    '''
    start, end = line_pos
    #lines = data['references'][start:end]
    #print('refs:', lines)
    #embeddings = data['embeddings'][start:end]
    #word_tokens = [[clean_word(w) for w in words] for words in data['word_tokens'][start:end]]
    #subword_tokens = data['subword_tokens'][start:end]
    #word_to_tokens_maps = data['word_to_tokens_maps'][start:end]

    keys = get_line_keys(data, line_pos)
    embeddings = [data[key]['embeddings'] for key in keys]
    word_tokens = [data[key]['word_tokens'] for key in keys]
    word_tokens = [[clean_word(w) for w in words] for words in word_tokens]
    subword_tokens = [data[key]['subword_tokens'] for key in keys]
    word_to_tokens_maps = [data[key]['word_to_tokens_maps'] for key in keys]
    pos_tags = [data[key]['pos_tags'] for key in keys]
    morph_tags = [data[key]['morph_tags'] for key in keys]
    print('refs:', keys)
    word_idx_to_ref = {i: key for i, key in enumerate(keys)}

    print('word tokens')
    for i, line in enumerate(word_tokens):
        print(i, line)
    
    # find words in bigram
    w1_line_idx, w1_idx = search_for_word(bigram[0], word_tokens)
    w2_line_idx, w2_idx = search_for_word(bigram[1], word_tokens)

    if w1_line_idx == -1 and w2_line_idx != -1:
        if bigram[1] in alt_phrase: alt_phrase.remove(bigram[1])
        alt_w1, alt_w1_score = find_closest_word(bigram[0], alt_phrase)
        w1_line_idx, w1_idx = search_for_word(alt_w1, word_tokens)
        print(f'  set alt w1 from {bigram[0]} to', alt_w1)
    elif w2_line_idx == -1 and w1_line_idx != -1:
        if bigram[0] in alt_phrase: alt_phrase.remove(bigram[0])
        alt_w2, alt_w2_score = find_closest_word(bigram[1], alt_phrase)
        w2_line_idx, w2_idx = search_for_word(alt_w2, word_tokens)
        print(f'  set alt w2 from {bigram[1]} to', alt_w2)
    elif w2_line_idx == -1 and w1_line_idx == -1:
        alt_w1, alt_w1_score = find_closest_word(bigram[0], alt_phrase)
        alt_w2, alt_w2_score = find_closest_word(bigram[1], alt_phrase)

        # want to use the word with the smallest edit distance first,
        # then remove that word from alt_phrase and find the second word
        if alt_w1_score < alt_w2_score:
            w1_line_idx, w1_idx = search_for_word(alt_w1, word_tokens)
            alt_phrase.remove(alt_w1)
            alt_w2, alt_w2_score = find_closest_word(bigram[1], alt_phrase)
            w2_line_idx, w2_idx = search_for_word(alt_w2, word_tokens)
        else:
            w2_line_idx, w2_idx = search_for_word(alt_w2, word_tokens)
            alt_phrase.remove(alt_w2)
            alt_w1, alt_w1_score = find_closest_word(bigram[0], alt_phrase)
            w1_line_idx, w1_idx = search_for_word(alt_w1, word_tokens)

        print(f'  set alt w1 from {bigram[0]} to', alt_w1)
        print(f'  set alt w2 from {bigram[1]} to', alt_w2)


    if w1_line_idx == -1 or w2_line_idx == -1:
        print(f'WARNING: bigram {bigram} not found in lines {start} to {end}')
        return None
    print('w1_line_idx, w1_idx:', w1_line_idx, w1_idx)
    print('word tokens:', word_tokens[w1_line_idx])
    print('subword tokens:', subword_tokens[w1_line_idx])
    print('w2_line_idx, w2_idx:', w2_line_idx, w2_idx)
    print('word tokens:', word_tokens[w2_line_idx])
    print('subword tokens:', subword_tokens[w2_line_idx])
    
    # get embeddings
    w1_subword_idx = word_to_tokens_maps[w1_line_idx][w1_idx]
    w2_subword_idx = word_to_tokens_maps[w2_line_idx][w2_idx]
    print('w1_subword_idx:', w1_subword_idx)
    print('w2_subword_idx:', w2_subword_idx)

    w1_embedding = embeddings[w1_line_idx][w1_subword_idx]
    w2_embedding = embeddings[w2_line_idx][w2_subword_idx]

    # average subword embeddings
    w1_embedding = np.mean(w1_embedding, axis=0)
    w2_embedding = np.mean(w2_embedding, axis=0)
    
    if DEBUG: print(f'Given bigram: {bigram}, found words: {word_tokens[w1_line_idx][w1_idx]} and {word_tokens[w2_line_idx][w2_idx]}')

    w1 = word_tokens[w1_line_idx][w1_idx]
    w2 = word_tokens[w2_line_idx][w2_idx]

    # also return indices with line offset
    w1_global_line = int(word_idx_to_ref[w1_line_idx].split('.')[-1])
    w2_global_line = int(word_idx_to_ref[w2_line_idx].split('.')[-1])

    w1_final_idx = (w1_idx, w1_global_line)
    w2_final_idx = (w2_idx, w2_global_line)

    # pos and morph tags
    w1_pos_tags = pos_tags[w1_line_idx][w1_idx]
    w2_pos_tags = pos_tags[w2_line_idx][w2_idx]
    w1_morph_tags = morph_tags[w1_line_idx][w1_idx]
    w2_morph_tags = morph_tags[w2_line_idx][w2_idx]

    return (w1_embedding, w2_embedding), (w1, w2), (w1_final_idx, w2_final_idx), (w1_pos_tags, w2_pos_tags), (w1_morph_tags, w2_morph_tags)

# %%
def get_gold_bigram_phrase(row: pd.Series):
    vf_bigram_phrase = row['Query'] # not actually lemmas
    vf_bigram_phrase = REPLACER.replace(vf_bigram_phrase)
    vf_bigram_phrase = vf_bigram_phrase.lower().split()

    alt_phrase = row['VF: Lemma']
    alt_phrase = REPLACER.replace(alt_phrase)
    alt_phrase = alt_phrase.lower().split()
    while '...' in alt_phrase:
        alt_phrase.remove('...')

    return vf_bigram_phrase, alt_phrase

# %%
row = comps.iloc[8]
vf_bigram_phrase, alt_phrase = get_gold_bigram_phrase(row)
vf_bigram_phrase
# Out:
# ['fatidicam', 'ratem']

# %%
start_idx = row['VF: Line Start'] - 2 # line start, not word start
if start_idx < 1:
    start_idx = 1
end_idx = start_idx + 5 #row['VF: Line End']
line_pos = (start_idx, end_idx)
interval = row['Interval']
vf_embeddings = get_bigram_embeddings(vf_bigram_phrase, alt_phrase, new_vf_data, line_pos)
# Out:
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['Prima', 'deum', 'magnis', 'canimus', 'freta', 'pervia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'Scythici', 'quae', 'Phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'Olympo', '.']
# 4 ['Phoebe', ',', 'mone', ',', 'si', 'Cumaeae', 'mihi', 'conscia', 'vatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 1 0
# word tokens: ['fatidicamque', 'ratem', ',', 'Scythici', 'quae', 'Phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w2_line_idx, w2_idx: 1 1
# word tokens: ['fatidicamque', 'ratem', ',', 'Scythici', 'quae', 'Phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w1_subword_idx: [1, 2, 3, 4]
# w2_subword_idx: [5]
# Given bigram: ['fatidicam', 'ratem'], found words: fatidicamque and ratem

# %%
def get_intertext_phrase(row: pd.Series):
    intertext_phrase = row['Result']
    intertext_phrase = REPLACER.replace(intertext_phrase)
    intertext_phrase = intertext_phrase.lower().split()
    
    alt_phrase = row['Intertext: Phrase']
    alt_phrase = REPLACER.replace(alt_phrase)
    # strip out punctuation
    alt_phrase = ''.join(char for char in alt_phrase if char.isalpha())
    alt_phrase = alt_phrase.lower().split()
    return intertext_phrase, alt_phrase

# %%
def compute_bigram_similarity(similarities: np.ndarray):
    best_idx = np.argmax(similarities)
    sim_1 = similarities[best_idx]
    # get index of position that doesn't contain the same word
    if best_idx == 0:
        pair_index = 3
    elif best_idx == 1:
        pair_index = 2
    elif best_idx == 2:
        pair_index = 1
    elif best_idx == 3:
        pair_index = 0

    sim_2 = similarities[pair_index]
    final_sim = (sim_1 + sim_2) / 2
    return final_sim

# %% [markdown]
# calculate bigram similarities and save to file

# %%
# cache of data, since we'll be accessing out of order
intertext_file_to_data = {}

# %%
# get embeddings
skip_idx = [67, 68, 525, 746, 839]
comps = pd.read_csv('../data/datasets/comps_paper.csv', index_col=0)

bert_query = []
bert_query_indices = []
bert_result = []
bert_result_indices = []
bert_pairs = []
bert_similarities = [] # 4 pair similarities per row
bert_similarity = [] # final similarities
query_pos = []
query_morph = []
result_pos = []
result_morph = []

for idx, row in comps.iterrows():
    if idx in skip_idx:
        bert_pairs.append(None)
        bert_similarities.append(None)
        bert_similarity.append(None)
        bert_query.append(None)
        bert_result.append(None)
        bert_query_indices.append(None)
        bert_result_indices.append(None)
        query_pos.append(None)
        query_morph.append(None)
        result_pos.append(None)
        result_morph.append(None)
        continue

    # get vf embeddings
    vf_bigram_phrase, alt_phrase = get_gold_bigram_phrase(row)
    
    start_line = row['VF: Line Start'] - 2
    if start_line < 1:
        start_line = 1
    end_line = start_line + 5

    if idx == 395:
        end_line += 3
    #line_pos = (start_idx, end_idx)
    line_pos = (start_line, end_line)
    #interval = row['Interval']
    if idx == 635:
        vf_bigram_phrase[0] = 'umme' # tokenization issue with roberta
    elif 870 <= idx <= 871:
        vf_bigram_phrase[0] = 'itte'
    
    vf_embeddings, vf_bigram, vf_bigram_indices, vf_pos_tags, vf_morph_tags = get_bigram_embeddings(vf_bigram_phrase, alt_phrase, new_vf_data, line_pos)

    # get intertext embeddings
    intertext_phrase, alt_phrase = get_intertext_phrase(row)
    intertext_file = row['file']
    intertext_data_file = EMBEDDINGS_FOLDER + f'/{intertext_file}.pos.pkl'

    if intertext_file not in intertext_file_to_data:
        intertext_data = load_data(intertext_data_file)

        # sort data by line number
        intertext_file_to_data[intertext_file] = sort_data(intertext_data)
    intertext_data = intertext_file_to_data[intertext_file]

    # get embeddings
    #start_idx = row['VF: Line Start'] - 1 # line start, not word start
    start_line = row['Intertext: Line Start'] - 2
    if start_line < 1:
        start_line = 1
    end_line = start_line + 5

    line_pos = (start_line, end_line)
    
    intertext_embeddings, intertext_bigram, intertext_bigram_indices, intertext_pos_tags, intertext_morph_tags = get_bigram_embeddings(intertext_phrase, alt_phrase, intertext_data, line_pos)

    # generate pairs
    pairs = list(product(vf_bigram, intertext_bigram))
    similarities = np.zeros((4,))
    indices = ((0, 0), (0, 1), (1, 0), (1, 1))
    for i, (vf_i, intertext_i) in enumerate(indices):
        vf_w, intertext_w = pairs[i]
        vf_emb = vf_embeddings[vf_i]
        intertext_emb = intertext_embeddings[intertext_i]
        # cosine similarity
        similarities[i] = np.dot(vf_emb, intertext_emb) / (np.linalg.norm(vf_emb) * np.linalg.norm(intertext_emb))

    # find highest similarity index
    final_sim = compute_bigram_similarity(similarities)

    bert_pairs.append(pairs)
    bert_similarities.append(similarities)
    bert_similarity.append(final_sim)
    bert_query.append(' '.join(vf_bigram))
    bert_result.append(' '.join(intertext_bigram))
    bert_query_indices.append(vf_bigram_indices)
    bert_result_indices.append(intertext_bigram_indices)
    query_pos.append(vf_pos_tags)
    query_morph.append(vf_morph_tags)
    result_pos.append(intertext_pos_tags)
    result_morph.append(intertext_morph_tags)
# Out:
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 0 0
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 0 3
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1]
# w2_subword_idx: [4]
# Given bigram: ['prima', 'canimus'], found words: prima and canimus
# refs: ['verg. aen. 1.1', 'verg. aen. 1.2', 'verg. aen. 1.3', 'verg. aen. 1.4', 'verg. aen. 1.5', 'verg. aen. 1.6']
# word tokens
# 0 ['arma', 'uirumque', 'cano', ',', 'troiae', 'qui', 'primus', 'ab', 'oris']
# 1 ['italiam', ',', 'fato', 'profugus', ',', 'lauiniaque', 'uenit']
# 2 ['litora', ',', 'multum', 'ille', 'et', 'terris', 'iactatus', 'et', 'alto']
# 3 ['ui', 'superum', 'saeuae', 'memorem', 'iunonis', 'ob', 'iram', ';']
# 4 ['multa', 'quoque', 'et', 'bello', 'passus', ',', 'dum', 'conderet', 'urbem', ',']
# 5 ['inferretque', 'deos', 'latio', ',', 'genus', 'unde', 'latinum', ',']
# w1_line_idx, w1_idx: 0 2
# word tokens: ['arma', 'uirumque', 'cano', ',', 'troiae', 'qui', 'primus', 'ab', 'oris']
# subword tokens: ['<s>', 'Arma', 'Ġvir', 'umque', 'Ġcano', ',', 'ĠTroiae', 'Ġqui', 'Ġprimus', 'Ġab', 'Ġoris', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 0 6
# word tokens: ['arma', 'uirumque', 'cano', ',', 'troiae', 'qui', 'primus', 'ab', 'oris']
# subword tokens: ['<s>', 'Arma', 'Ġvir', 'umque', 'Ġcano', ',', 'ĠTroiae', 'Ġqui', 'Ġprimus', 'Ġab', 'Ġoris', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [4]
# w2_subword_idx: [8]
# Given bigram: ['cano', 'primus'], found words: cano and primus
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 0 0
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 0 3
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1]
# w2_subword_idx: [4]
# Given bigram: ['prima', 'canimus'], found words: prima and canimus
# refs: ['stat. theb. 1.2', 'stat. theb. 1.3', 'stat. theb. 1.4', 'stat. theb. 1.5', 'stat. theb. 1.6', 'stat. theb. 1.7']
# word tokens
# 0 ['decertata', 'odiis', 'sontesque', 'euoluere', 'thebas', ',']
# 1 ['pierius', 'menti', 'calor', 'incidit', ',', 'unde', 'iubetis']
# 2 ['ire', ',', 'deae', '?', 'gentisne', 'canam', 'primordia', 'dirae', ',']
# 3 ['sidonios', 'raptus', 'et', 'inexorabile', 'pactum']
# 4 ['legis', 'agenoreae', 'scrutantemque', 'aequora', 'cadmum', '?']
# 5 ['longa', 'retro', 'series', ',', 'trepidum', 'si', 'martis', 'operti']
# w1_line_idx, w1_idx: 2 5
# word tokens: ['ire', ',', 'deae', '?', 'gentisne', 'canam', 'primordia', 'dirae', ',']
# subword tokens: ['<s>', 'ire', ',', 'Ġdeae', '?', 'Ġgentis', 'ne', 'Ġcan', 'am', 'Ġprimordia', 'Ġdirae', ',', '</s>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 6
# word tokens: ['ire', ',', 'deae', '?', 'gentisne', 'canam', 'primordia', 'dirae', ',']
# subword tokens: ['<s>', 'ire', ',', 'Ġdeae', '?', 'Ġgentis', 'ne', 'Ġcan', 'am', 'Ġprimordia', 'Ġdirae', ',', '</s>', '<pad>', '<pad>']
# w1_subword_idx: [7, 8]
# w2_subword_idx: [9]
# Given bigram: ['canam', 'primordia'], found words: canam and primordia
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 0 0
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 1
# word tokens: ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# subword tokens: ['<s>', 'aus', 'a', 'Ġsequi', 'Ġmedi', 'osque', 'Ġinter', 'Ġiuga', 'Ġconcita', 'Ġcursus', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1]
# w2_subword_idx: [3]
# Given bigram: ['prima', 'sequi'], found words: prima and sequi
# refs: ['verg. aen. 7.645', 'verg. aen. 7.646', 'verg. aen. 7.647', 'verg. aen. 7.648', 'verg. aen. 7.649', 'verg. aen. 7.650']
# word tokens
# 0 ['et', 'meministis', 'enim', ',', 'diuae', ',', 'et', 'memorare', 'potestis', ':']
# 1 ['ad', 'nos', 'uix', 'tenuis', 'famae', 'perlabitur', 'aura', '.']
# 2 ['primus', 'init', 'bellum', 'tyrrhenis', 'asper', 'ab', 'oris']
# 3 ['contemptor', 'diuom', 'mezentius', 'agminaque', 'armat', '.']
# 4 ['filius', 'huic', 'iuxta', 'lausus', ',', 'quo', 'pulchrior', 'alter']
# 5 ['non', 'fuit', 'excepto', 'laurentis', 'corpore', 'turni', ',']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['primus', 'init', 'bellum', 'tyrrhenis', 'asper', 'ab', 'oris']
# subword tokens: ['<s>', 'Primus', 'Ġinit', 'Ġbellum', 'ĠTyrrh', 'enis', 'Ġasper', 'Ġab', 'Ġoris', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 1
# word tokens: ['primus', 'init', 'bellum', 'tyrrhenis', 'asper', 'ab', 'oris']
# subword tokens: ['<s>', 'Primus', 'Ġinit', 'Ġbellum', 'ĠTyrrh', 'enis', 'Ġasper', 'Ġab', 'Ġoris', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1]
# w2_subword_idx: [2]
# Given bigram: ['primus', 'init'], found words: primus and init
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 0 0
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 0 1
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1]
# w2_subword_idx: [2]
# Given bigram: ['prima', 'deum'], found words: prima and deum
# refs: ['luc. 5.459', 'luc. 5.460', 'luc. 5.461', 'luc. 5.462', 'luc. 5.463', 'luc. 5.464']
# word tokens
# 0 ['curua', 'sequi', ',', 'quae', 'iam', 'uento', 'fluctuque', 'secundo']
# 1 ['lapsa', 'palaestinas', 'uncis', 'confixit', 'arenas', '.']
# 2 ['prima', 'duces', 'uidit', 'iunctis', 'consistere', 'castris']
# 3 ['tellus', ',', 'quam', 'uolucer', 'genusus', ',', 'quam', 'mollior', 'apsus']
# 4 ['circueunt', 'ripis', '.', 'apso', 'gestare', 'carinas']
# 5 ['caussa', 'palus', ',', 'leni', 'quam', 'fallens', 'egerit', 'unda', '.']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['prima', 'duces', 'uidit', 'iunctis', 'consistere', 'castris']
# subword tokens: ['<s>', 'Prima', 'Ġduces', 'Ġvidit', 'Ġiunctis', 'Ġconsistere', 'Ġcastris', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 1
# word tokens: ['prima', 'duces', 'uidit', 'iunctis', 'consistere', 'castris']
# subword tokens: ['<s>', 'Prima', 'Ġduces', 'Ġvidit', 'Ġiunctis', 'Ġconsistere', 'Ġcastris', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1]
# w2_subword_idx: [2]
# Given bigram: ['prima', 'duces'], found words: prima and duces
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 0 0
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 0 2
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1]
# w2_subword_idx: [3]
# Given bigram: ['prima', 'magnis'], found words: prima and magnis
# refs: ['stat. theb. 4.3', 'stat. theb. 4.4', 'stat. theb. 4.5', 'stat. theb. 4.6', 'stat. theb. 4.7', 'stat. theb. 4.8']
# word tokens
# 0 ['longius', 'ire', 'diem', ',', 'eum', 'fracta', 'impulsaque', 'fatis']
# 1 ['consilia', 'et', 'tandem', 'miseri', 'data', 'copia', 'belli', ',']
# 2 ['prima', 'manu', 'rutilam', 'de', 'uertice', 'larissaco']
# 3 ['ostendit', 'bellona', 'facem', 'dextraque', 'trabalem']
# 4 ['hastam', 'intorsit', 'agens', ',', 'liquido', 'quae', 'stridula', 'caelo']
# 5 ['fugit', 'et', 'aoniae', 'celso', 'stetit', 'aggere', 'dirces', '.']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['prima', 'manu', 'rutilam', 'de', 'uertice', 'larissaco']
# subword tokens: ['<s>', 'prima', 'Ġmanu', 'Ġruti', 'lam', 'Ġde', 'Ġvertice', 'ĠLar', 'iss', 'aco', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 1
# word tokens: ['prima', 'manu', 'rutilam', 'de', 'uertice', 'larissaco']
# subword tokens: ['<s>', 'prima', 'Ġmanu', 'Ġruti', 'lam', 'Ġde', 'Ġvertice', 'ĠLar', 'iss', 'aco', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1]
# w2_subword_idx: [2]
# Given bigram: ['prima', 'manu'], found words: prima and manu
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 0 3
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 0 4
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [4]
# w2_subword_idx: [5]
# Given bigram: ['canimus', 'freta'], found words: canimus and freta
# refs: ['luc. 1.1', 'luc. 1.2', 'luc. 1.3', 'luc. 1.4', 'luc. 1.5', 'luc. 1.6']
# word tokens
# 0 ['bella', 'per', 'emathios', 'plus', 'quam', 'ciuilia', 'campos']
# 1 ['iusque', 'datum', '', 'sceleri', 'canimus', ',', 'populumque', 'potentem']
# 2 ['in', 'sua', 'uictrici', 'conuersum', 'uiscera', 'dextra', ',']
# 3 ['cognatasque', 'acies', ',', 'et', 'rupto', 'foedere', 'regni', ',']
# 4 ['certatum', 'totis', 'concussi', 'uiribus', 'orbis']
# 5 ['in', 'commune', 'nefas', ',', 'infestisque', 'obuia', 'signis']
# w1_line_idx, w1_idx: 1 0
# word tokens: ['iusque', 'datum', '', 'sceleri', 'canimus', ',', 'populumque', 'potentem']
# subword tokens: ['<s>', 'I', 'usque', 'Ġdatum', 'Ġ', 'Ġsceleri', 'Ġcanimus', ',', 'Ġpopulumque', 'Ġpotentem', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 1 4
# word tokens: ['iusque', 'datum', '', 'sceleri', 'canimus', ',', 'populumque', 'potentem']
# subword tokens: ['<s>', 'I', 'usque', 'Ġdatum', 'Ġ', 'Ġsceleri', 'Ġcanimus', ',', 'Ġpopulumque', 'Ġpotentem', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1, 2]
# w2_subword_idx: [6]
# Given bigram: ['iusque', 'canimus'], found words: iusque and canimus
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 0 0
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 0 3
# word tokens: ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# subword tokens: ['<s>', 'Prima', 'Ġdeum', 'Ġmagnis', 'Ġcanimus', 'Ġfreta', 'Ġpervia', 'Ġnatis', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1]
# w2_subword_idx: [4]
# Given bigram: ['prima', 'canimus'], found words: prima and canimus
# refs: ['stat. theb. 1.2', 'stat. theb. 1.3', 'stat. theb. 1.4', 'stat. theb. 1.5', 'stat. theb. 1.6', 'stat. theb. 1.7']
# word tokens
# 0 ['decertata', 'odiis', 'sontesque', 'euoluere', 'thebas', ',']
# 1 ['pierius', 'menti', 'calor', 'incidit', ',', 'unde', 'iubetis']
# 2 ['ire', ',', 'deae', '?', 'gentisne', 'canam', 'primordia', 'dirae', ',']
# 3 ['sidonios', 'raptus', 'et', 'inexorabile', 'pactum']
# 4 ['legis', 'agenoreae', 'scrutantemque', 'aequora', 'cadmum', '?']
# 5 ['longa', 'retro', 'series', ',', 'trepidum', 'si', 'martis', 'operti']
# w1_line_idx, w1_idx: 2 4
# word tokens: ['ire', ',', 'deae', '?', 'gentisne', 'canam', 'primordia', 'dirae', ',']
# subword tokens: ['<s>', 'ire', ',', 'Ġdeae', '?', 'Ġgentis', 'ne', 'Ġcan', 'am', 'Ġprimordia', 'Ġdirae', ',', '</s>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 5
# word tokens: ['ire', ',', 'deae', '?', 'gentisne', 'canam', 'primordia', 'dirae', ',']
# subword tokens: ['<s>', 'ire', ',', 'Ġdeae', '?', 'Ġgentis', 'ne', 'Ġcan', 'am', 'Ġprimordia', 'Ġdirae', ',', '</s>', '<pad>', '<pad>']
# w1_subword_idx: [5, 6]
# w2_subword_idx: [7, 8]
# Given bigram: ['gentisne', 'canam'], found words: gentisne and canam
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 1 0
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w2_line_idx, w2_idx: 1 1
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w1_subword_idx: [1, 2, 3, 4]
# w2_subword_idx: [5]
# Given bigram: ['fatidicam', 'ratem'], found words: fatidicamque and ratem
# refs: ['verg. aen. 7.80', 'verg. aen. 7.81', 'verg. aen. 7.82', 'verg. aen. 7.83', 'verg. aen. 7.84', 'verg. aen. 7.85']
# word tokens
# 0 ['ipsam', ',', 'sed', 'populo', 'magnum', 'portendere', 'bellum', '.']
# 1 ['at', 'rex', 'sollicitus', 'monstris', 'oracula', 'fauni', ',']
# 2 ['fatidici', ';', 'genitoris', ',', 'adit', 'lucosque', 'sub', 'alta']
# 3 ['consulit', 'albunea', ',', 'nemorum', 'quae', 'maxima', 'sacro']
# 4 ['fonte', 'sonat', 'saeuamque', 'exhalat', 'opaca', 'mephitim', '.']
# 5 ['hinc', 'italae', 'gentes', 'omnisque', 'oenotria', 'tellus']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['fatidici', ';', 'genitoris', ',', 'adit', 'lucosque', 'sub', 'alta']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'i', ';', 'Ġgenitoris', ',', 'Ġadit', 'Ġluc', 'osque', 'Ġsub', 'Ġalta', '</s>', '<pad>']
# w2_line_idx, w2_idx: 2 4
# word tokens: ['fatidici', ';', 'genitoris', ',', 'adit', 'lucosque', 'sub', 'alta']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'i', ';', 'Ġgenitoris', ',', 'Ġadit', 'Ġluc', 'osque', 'Ġsub', 'Ġalta', '</s>', '<pad>']
# w1_subword_idx: [1, 2, 3, 4]
# w2_subword_idx: [8]
# Given bigram: ['fatidici', 'adit'], found words: fatidici and adit
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 1 0
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w2_line_idx, w2_idx: 1 1
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w1_subword_idx: [1, 2, 3, 4]
# w2_subword_idx: [5]
# Given bigram: ['fatidicam', 'ratem'], found words: fatidicamque and ratem
# refs: ['verg. aen. 8.338', 'verg. aen. 8.339', 'verg. aen. 8.340', 'verg. aen. 8.341', 'verg. aen. 8.342', 'verg. aen. 8.343']
# word tokens
# 0 ['et', 'carmentalem', 'romani', 'nomine', 'portam']
# 1 ['quam', 'memorant', ',', 'nymphae', 'priscum', 'carmentis', 'honorem', ',']
# 2 ['uatis', 'fatidicae', ',', 'cecinit', 'quae', 'prima', 'futuros']
# 3 ['aeneadas', 'magnos', 'et', 'nobile', 'pallanteum', '.']
# 4 ['hinc', 'lucum', 'ingentem', 'quem', 'romulus', 'acer', 'asylum']
# 5 ['rettulit', 'et', 'gelida', 'monstrat', 'sub', 'rupe', 'lupercal', ',']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['uatis', 'fatidicae', ',', 'cecinit', 'quae', 'prima', 'futuros']
# subword tokens: ['<s>', 'v', 'atis', 'Ġfati', 'dic', 'ae', ',', 'Ġcecinit', 'Ġquae', 'Ġprima', 'Ġfuturos', '</s>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 1
# word tokens: ['uatis', 'fatidicae', ',', 'cecinit', 'quae', 'prima', 'futuros']
# subword tokens: ['<s>', 'v', 'atis', 'Ġfati', 'dic', 'ae', ',', 'Ġcecinit', 'Ġquae', 'Ġprima', 'Ġfuturos', '</s>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1, 2]
# w2_subword_idx: [3, 4, 5]
# Given bigram: ['uatis', 'fatidicae'], found words: uatis and fatidicae
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 1 0
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w2_line_idx, w2_idx: 1 1
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w1_subword_idx: [1, 2, 3, 4]
# w2_subword_idx: [5]
# Given bigram: ['fatidicam', 'ratem'], found words: fatidicamque and ratem
# refs: ['verg. aen. 10.197', 'verg. aen. 10.198', 'verg. aen. 10.199', 'verg. aen. 10.200', 'verg. aen. 10.201', 'verg. aen. 10.202']
# word tokens
# 0 ['arduus', 'et', 'longa', 'sulcat', 'maria', 'alta', 'carina', '.']
# 1 ['ille', 'etiam', 'patriis', 'agmen', 'ciet', 'ocnus', 'ab', 'oris', ',']
# 2 ['fatidicae', 'mantus', 'et', 'tusci', 'filius', 'amnis', ',']
# 3 ['qui', 'muros', 'matrisque', 'dedit', 'tibi', ',', 'mantua', ',', 'nomen', ',']
# 4 ['mantua', ',', 'diues', 'auis', ';', 'sed', 'non', 'genus', 'omnibus', 'unum', ':']
# 5 ['gens', 'illi', 'triplex', ',', 'populi', 'sub', 'gente', 'quaterni', ',']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['fatidicae', 'mantus', 'et', 'tusci', 'filius', 'amnis', ',']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'ae', 'ĠMant', 'us', 'Ġet', 'ĠTus', 'ci', 'Ġfilius', 'Ġamnis', ',', '</s>', '<pad>']
# w2_line_idx, w2_idx: 2 1
# word tokens: ['fatidicae', 'mantus', 'et', 'tusci', 'filius', 'amnis', ',']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'ae', 'ĠMant', 'us', 'Ġet', 'ĠTus', 'ci', 'Ġfilius', 'Ġamnis', ',', '</s>', '<pad>']
# w1_subword_idx: [1, 2, 3, 4]
# w2_subword_idx: [5, 6]
# Given bigram: ['fatidicae', 'mantus'], found words: fatidicae and mantus
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 1 5
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w2_line_idx, w2_idx: 1 6
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w1_subword_idx: [10, 11]
# w2_subword_idx: [12]
# Given bigram: ['phasidis', 'oras'], found words: phasidis and oras
# refs: ['ov. met. 7.436', 'ov. met. 7.437', 'ov. met. 7.438', 'ov. met. 7.439', 'ov. met. 7.440', 'ov. met. 7.441']
# word tokens
# 0 ['munus', 'opusque', 'tuum', 'est', '.', 'tellus', 'epidauria', 'per', 'te']
# 1 ['clauigeram', 'uidit', 'uulcani', 'occumbere', 'prolem', ',']
# 2 ['uidit', 'et', 'inmitem', 'cephisias', 'ora', 'procrusten', ',']
# 3 ['cercyonis', 'letum', 'uidit', 'cerealis', 'eleusin', '.']
# 4 ['occidit', 'ille', 'sinis', ',', 'magnis', 'male', 'uiribus', 'usus', ',']
# 5 ['qui', 'poterat', 'curuare', 'trabes', 'et', 'agebat', 'ab', 'alto']
# w1_line_idx, w1_idx: 2 3
# word tokens: ['uidit', 'et', 'inmitem', 'cephisias', 'ora', 'procrusten', ',']
# subword tokens: ['<s>', 'v', 'idit', 'Ġet', 'Ġinm', 'item', 'ĠCeph', 'isi', 'as', 'Ġora', 'ĠPr', 'ocr', 'ust', 'en', ',', '</s>']
# w2_line_idx, w2_idx: 2 4
# word tokens: ['uidit', 'et', 'inmitem', 'cephisias', 'ora', 'procrusten', ',']
# subword tokens: ['<s>', 'v', 'idit', 'Ġet', 'Ġinm', 'item', 'ĠCeph', 'isi', 'as', 'Ġora', 'ĠPr', 'ocr', 'ust', 'en', ',', '</s>']
# w1_subword_idx: [6, 7, 8]
# w2_subword_idx: [9]
# Given bigram: ['cephisias', 'ora'], found words: cephisias and ora
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 1 5
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w2_line_idx, w2_idx: 1 6
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w1_subword_idx: [10, 11]
# w2_subword_idx: [12]
# Given bigram: ['phasidis', 'oras'], found words: phasidis and oras
# refs: ['verg. aen. 1.1', 'verg. aen. 1.2', 'verg. aen. 1.3', 'verg. aen. 1.4', 'verg. aen. 1.5', 'verg. aen. 1.6']
# word tokens
# 0 ['arma', 'uirumque', 'cano', ',', 'troiae', 'qui', 'primus', 'ab', 'oris']
# 1 ['italiam', ',', 'fato', 'profugus', ',', 'lauiniaque', 'uenit']
# 2 ['litora', ',', 'multum', 'ille', 'et', 'terris', 'iactatus', 'et', 'alto']
# 3 ['ui', 'superum', 'saeuae', 'memorem', 'iunonis', 'ob', 'iram', ';']
# 4 ['multa', 'quoque', 'et', 'bello', 'passus', ',', 'dum', 'conderet', 'urbem', ',']
# 5 ['inferretque', 'deos', 'latio', ',', 'genus', 'unde', 'latinum', ',']
# w1_line_idx, w1_idx: 0 8
# word tokens: ['arma', 'uirumque', 'cano', ',', 'troiae', 'qui', 'primus', 'ab', 'oris']
# subword tokens: ['<s>', 'Arma', 'Ġvir', 'umque', 'Ġcano', ',', 'ĠTroiae', 'Ġqui', 'Ġprimus', 'Ġab', 'Ġoris', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 1 0
# word tokens: ['italiam', ',', 'fato', 'profugus', ',', 'lauiniaque', 'uenit']
# subword tokens: ['<s>', 'Ita', 'liam', ',', 'Ġfato', 'Ġprofugus', ',', 'ĠLav', 'inia', 'que', 'Ġvenit', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [10]
# w2_subword_idx: [1, 2]
# Given bigram: ['oris', 'italiam'], found words: oris and italiam
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 1 5
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w2_line_idx, w2_idx: 1 6
# word tokens: ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# subword tokens: ['<s>', 'f', 'ati', 'dic', 'amque', 'Ġratem', ',', 'ĠScyth', 'ici', 'Ġquae', 'ĠPhas', 'idis', 'Ġoras', '</s>', '<pad>']
# w1_subword_idx: [10, 11]
# w2_subword_idx: [12]
# Given bigram: ['phasidis', 'oras'], found words: phasidis and oras
# refs: ['stat. theb. 12.180', 'stat. theb. 12.181', 'stat. theb. 12.182', 'stat. theb. 12.183', 'stat. theb. 12.184', 'stat. theb. 12.185']
# word tokens
# 0 ['comminus', 'infandi', 'leges', 'accedere', 'regni', ',']
# 1 ['quo', 'rhodopes', 'non', 'ulla', 'nurus', 'nec', 'alumna', 'niuosi']
# 2 ['phasidis', 'innuptis', 'uallata', 'cohortibus', 'iret', '.']
# 3 ['tunc', 'mouet', 'arte', 'dolum', ',', 'quo', 'semet', 'ab', 'agmine', 'fido']
# 4 ['degreget', ',', 'immitesque', 'deos', 'regemque', 'cruentum']
# 5 ['contemptrix', 'animae', 'et', 'magno', 'temeraria', 'luctu']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['phasidis', 'innuptis', 'uallata', 'cohortibus', 'iret', '.']
# subword tokens: ['<s>', 'Ph', 'as', 'idis', 'Ġinnup', 'tis', 'Ġvall', 'ata', 'Ġcohortibus', 'Ġiret', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 1
# word tokens: ['phasidis', 'innuptis', 'uallata', 'cohortibus', 'iret', '.']
# subword tokens: ['<s>', 'Ph', 'as', 'idis', 'Ġinnup', 'tis', 'Ġvall', 'ata', 'Ġcohortibus', 'Ġiret', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1, 2, 3]
# w2_subword_idx: [4, 5]
# Given bigram: ['phasidis', 'innuptis'], found words: phasidis and innuptis
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# subword tokens: ['<s>', 'aus', 'a', 'Ġsequi', 'Ġmedi', 'osque', 'Ġinter', 'Ġiuga', 'Ġconcita', 'Ġcursus', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 1
# word tokens: ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# subword tokens: ['<s>', 'aus', 'a', 'Ġsequi', 'Ġmedi', 'osque', 'Ġinter', 'Ġiuga', 'Ġconcita', 'Ġcursus', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1, 2]
# w2_subword_idx: [3]
# Given bigram: ['ausa', 'sequi'], found words: ausa and sequi
# refs: ['verg. aen. 7.298', 'verg. aen. 7.299', 'verg. aen. 7.300', 'verg. aen. 7.301', 'verg. aen. 7.302', 'verg. aen. 7.303']
# word tokens
# 0 ['fessa', 'iacent', 'odiis', 'aut', 'exsaturata', 'quieui', '.']
# 1 ['quin', 'etiam', 'patria', 'excussos', 'infesta', 'per', 'undas']
# 2 ['ausa', 'sequi', 'et', 'profugis', 'toto', 'me', 'opponere', 'ponto', '!']
# 3 ['absumptae', 'in', 'teucros', 'uires', 'caelique', 'marisque', '.']
# 4 ['quid', 'syrtes', 'aut', 'scylla', 'mihi', ',', 'quid', 'uasta', 'charybdis']
# 5 ['profuit', '?', 'optato', 'conduntur', 'thybridis', 'alueo', ',']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['ausa', 'sequi', 'et', 'profugis', 'toto', 'me', 'opponere', 'ponto', '!']
# subword tokens: ['<s>', 'aus', 'a', 'Ġsequi', 'Ġet', 'Ġprofug', 'is', 'Ġtoto', 'Ġme', 'Ġopponere', 'Ġponto', 'Ġ!', '</s>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 1
# word tokens: ['ausa', 'sequi', 'et', 'profugis', 'toto', 'me', 'opponere', 'ponto', '!']
# subword tokens: ['<s>', 'aus', 'a', 'Ġsequi', 'Ġet', 'Ġprofug', 'is', 'Ġtoto', 'Ġme', 'Ġopponere', 'Ġponto', 'Ġ!', '</s>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1, 2]
# w2_subword_idx: [3]
# Given bigram: ['ausa', 'sequi'], found words: ausa and sequi
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# subword tokens: ['<s>', 'aus', 'a', 'Ġsequi', 'Ġmedi', 'osque', 'Ġinter', 'Ġiuga', 'Ġconcita', 'Ġcursus', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 1
# word tokens: ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# subword tokens: ['<s>', 'aus', 'a', 'Ġsequi', 'Ġmedi', 'osque', 'Ġinter', 'Ġiuga', 'Ġconcita', 'Ġcursus', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1, 2]
# w2_subword_idx: [3]
# Given bigram: ['ausa', 'sequi'], found words: ausa and sequi
# refs: ['verg. aen. 4.359', 'verg. aen. 4.360', 'verg. aen. 4.361', 'verg. aen. 4.362', 'verg. aen. 4.363', 'verg. aen. 4.364']
# word tokens
# 0 ['intrantem', 'muros', ',', 'uocemque', 'his', 'auribus', 'hausi', '.']
# 1 ['desine', 'meque', 'tuis', 'incendere', 'teque', 'querelis', ':']
# 2 ['italiam', 'non', 'sponte', 'sequor', '."']
# 3 ['talia', 'dicentem', 'iamdudum', 'auersa', 'tuetur', ',']
# 4 ['huc', 'illuc', 'uoluens', 'oculos', ',', 'totumque', 'pererrat']
# 5 ['luminibus', 'tacitis', ',', 'et', 'sic', 'accensa', 'profatur', ':']
# w1_line_idx, w1_idx: 2 2
# word tokens: ['italiam', 'non', 'sponte', 'sequor', '."']
# subword tokens: ['<s>', 'Ita', 'liam', 'Ġnon', 'Ġsponte', 'Ġsequor', '."', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 3
# word tokens: ['italiam', 'non', 'sponte', 'sequor', '."']
# subword tokens: ['<s>', 'Ita', 'liam', 'Ġnon', 'Ġsponte', 'Ġsequor', '."', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [4]
# w2_subword_idx: [5]
# Given bigram: ['sponte', 'sequor'], found words: sponte and sequor
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 2 2
# word tokens: ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# subword tokens: ['<s>', 'aus', 'a', 'Ġsequi', 'Ġmedi', 'osque', 'Ġinter', 'Ġiuga', 'Ġconcita', 'Ġcursus', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 3
# word tokens: ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# subword tokens: ['<s>', 'aus', 'a', 'Ġsequi', 'Ġmedi', 'osque', 'Ġinter', 'Ġiuga', 'Ġconcita', 'Ġcursus', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [4, 5]
# w2_subword_idx: [6]
# Given bigram: ['medios', 'inter'], found words: mediosque and inter
# refs: ['verg. aen. 1.346', 'verg. aen. 1.347', 'verg. aen. 1.348', 'verg. aen. 1.349', 'verg. aen. 1.350', 'verg. aen. 1.351']
# word tokens
# 0 ['ominibus', '.', 'sed', 'regna', 'tyri', 'germanus', 'habebat']
# 1 ['pygmalion', ',', 'scelere', 'ante', 'alios', 'immanior', 'omnes', '.']
# 2 ['quos', 'inter', 'medius', 'uenit', 'furor', '.', 'ille', 'sychaeum']
# 3 ['impius', 'ante', 'aras', ',', 'atque', 'auri', 'caecus', 'amore', ',']
# 4 ['clam', 'ferro', 'incautum', 'superat', ',', 'securus', 'amorum']
# 5 ['germanae', ';', 'factumque', 'diu', 'celauit', ',', 'et', 'aegram', ',']
# w1_line_idx, w1_idx: 2 1
# word tokens: ['quos', 'inter', 'medius', 'uenit', 'furor', '.', 'ille', 'sychaeum']
# subword tokens: ['<s>', 'Quos', 'Ġinter', 'Ġmedius', 'Ġvenit', 'Ġfuror', '.', 'ĠIlle', 'ĠSy', 'ch', 'aeum', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 2
# word tokens: ['quos', 'inter', 'medius', 'uenit', 'furor', '.', 'ille', 'sychaeum']
# subword tokens: ['<s>', 'Quos', 'Ġinter', 'Ġmedius', 'Ġvenit', 'Ġfuror', '.', 'ĠIlle', 'ĠSy', 'ch', 'aeum', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [2]
# w2_subword_idx: [3]
# Given bigram: ['inter', 'medius'], found words: inter and medius
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 2 6
# word tokens: ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# subword tokens: ['<s>', 'aus', 'a', 'Ġsequi', 'Ġmedi', 'osque', 'Ġinter', 'Ġiuga', 'Ġconcita', 'Ġcursus', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 3 0
# word tokens: ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# subword tokens: ['<s>', 'rump', 'ere', 'Ġflamm', 'ifer', 'o', 'Ġtandem', 'Ġconsedit', 'ĠOlympo', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [9]
# w2_subword_idx: [1, 2]
# Given bigram: ['cursus', 'rumpere'], found words: cursus and rumpere
# refs: ['verg. aen. 2.492', 'verg. aen. 2.493', 'verg. aen. 2.494', 'verg. aen. 2.495', 'verg. aen. 2.496', 'verg. aen. 2.497']
# word tokens
# 0 ['custodes', 'sufferre', 'ualent', ';', 'labat', 'ariete', 'crebro']
# 1 ['ianua', ',', 'et', 'emoti', 'procumbunt', 'cardine', 'postes', '.']
# 2 ['fit', 'uia', 'ui', ';', 'rumpunt', 'aditus', ',', 'primosque', 'trucidant']
# 3 ['immissi', 'danai', ',', 'et', 'late', 'loca', 'milite', 'complent', '.']
# 4 ['non', 'sic', ',', 'aggeribus', 'ruptis', 'cum', 'spumeus', 'amnis']
# 5 ['exiit', ',', 'oppositasque', 'euicit', 'gurgite', 'moles', ',']
# w1_line_idx, w1_idx: 2 4
# word tokens: ['fit', 'uia', 'ui', ';', 'rumpunt', 'aditus', ',', 'primosque', 'trucidant']
# subword tokens: ['<s>', 'Fit', 'Ġvia', 'Ġvi', ';', 'Ġrump', 'unt', 'Ġaditus', ',', 'Ġprim', 'osque', 'Ġtrucid', 'ant', '</s>', '<pad>']
# w2_line_idx, w2_idx: 2 5
# word tokens: ['fit', 'uia', 'ui', ';', 'rumpunt', 'aditus', ',', 'primosque', 'trucidant']
# subword tokens: ['<s>', 'Fit', 'Ġvia', 'Ġvi', ';', 'Ġrump', 'unt', 'Ġaditus', ',', 'Ġprim', 'osque', 'Ġtrucid', 'ant', '</s>', '<pad>']
# w1_subword_idx: [5, 6]
# w2_subword_idx: [7]
# Given bigram: ['rumpunt', 'aditus'], found words: rumpunt and aditus
# refs: ['valerius flaccus 1.1', 'valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6']
# word tokens
# 0 ['prima', 'deum', 'magnis', 'canimus', 'freta', 'peruia', 'natis']
# 1 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 2 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 3 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 4 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 5 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# w1_line_idx, w1_idx: 2 6
# word tokens: ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# subword tokens: ['<s>', 'aus', 'a', 'Ġsequi', 'Ġmedi', 'osque', 'Ġinter', 'Ġiuga', 'Ġconcita', 'Ġcursus', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 3 0
# word tokens: ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# subword tokens: ['<s>', 'rump', 'ere', 'Ġflamm', 'ifer', 'o', 'Ġtandem', 'Ġconsedit', 'ĠOlympo', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [9]
# w2_subword_idx: [1, 2]
# Given bigram: ['cursus', 'rumpere'], found words: cursus and rumpere
# refs: ['verg. aen. 10.370', 'verg. aen. 10.371', 'verg. aen. 10.372', 'verg. aen. 10.373', 'verg. aen. 10.374', 'verg. aen. 10.375']
# word tokens
# 0 ['per', 'ducis', 'euandri', 'nomen', 'deuictaque', 'bella']
# 1 ['opemque', 'meam', ',', 'patriae', 'quae', 'nunc', 'subit', 'aemula', 'laudi', ',']
# 2 ['fidite', 'ne', 'pedibus', '.', 'ferro', 'rumpenda', 'per', 'hostis']
# 3 ['est', 'uia', '.', 'qua', 'globus', 'ille', 'uirum', 'densissimus', 'urget', ',']
# 4 ['hac', 'uos', 'et', 'pallanta', 'ducem', 'patria', 'alta', 'reposcit', '.']
# 5 ['numina', 'nulla', 'premunt', ',', 'mortali', 'urgemur', 'ab', 'hoste']
# w1_line_idx, w1_idx: 2 4
# word tokens: ['fidite', 'ne', 'pedibus', '.', 'ferro', 'rumpenda', 'per', 'hostis']
# subword tokens: ['<s>', 'fid', 'ite', 'Ġne', 'Ġpedibus', '.', 'ĠFer', 'ro', 'Ġrump', 'enda', 'Ġper', 'Ġhostis', '</s>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 5
# word tokens: ['fidite', 'ne', 'pedibus', '.', 'ferro', 'rumpenda', 'per', 'hostis']
# subword tokens: ['<s>', 'fid', 'ite', 'Ġne', 'Ġpedibus', '.', 'ĠFer', 'ro', 'Ġrump', 'enda', 'Ġper', 'Ġhostis', '</s>', '<pad>', '<pad>']
# w1_subword_idx: [6, 7]
# w2_subword_idx: [8, 9]
# Given bigram: ['ferro', 'rumpenda'], found words: ferro and rumpenda
# refs: ['valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6', 'valerius flaccus 1.7']
# word tokens
# 0 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 1 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 2 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 3 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 4 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# 5 ['fronte', 'uiret', ',', 'tuque', 'o', 'pelagi', 'cui', 'maior', 'aperti']
# w1_line_idx, w1_idx: 2 1
# word tokens: ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# subword tokens: ['<s>', 'rump', 'ere', 'Ġflamm', 'ifer', 'o', 'Ġtandem', 'Ġconsedit', 'ĠOlympo', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 4
# word tokens: ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# subword tokens: ['<s>', 'rump', 'ere', 'Ġflamm', 'ifer', 'o', 'Ġtandem', 'Ġconsedit', 'ĠOlympo', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [3, 4, 5]
# w2_subword_idx: [8]
# Given bigram: ['flammifero', 'olympo'], found words: flammifero and olympo
# refs: ['luc. 5.400', 'luc. 5.401', 'luc. 5.402', 'luc. 5.403', 'luc. 5.404', 'luc. 5.405']
# word tokens
# 0 ['nec', 'non', 'iliacae', 'numen', 'quod', 'praesidet', 'albae', ',']
# 1 ['haud', 'meritum', 'latio', 'sollemnia', 'sacra', 'subacto', ',']
# 2 ['uidit', 'flammifera', 'confectas', 'nocte', 'latinas', '.']
# 3 ['inde', 'rapit', 'cursus', ',', 'et', ',', 'quae', 'piger', 'appulus', 'arua']
# 4 ['deseruit', 'rastris', ',', 'et', 'inerti', 'tradidit', 'herbae', ',']
# 5 ['ocior', 'et', 'coeli', 'flammis', 'et', 'tigride', 'foeta']
# w1_line_idx, w1_idx: 2 1
# word tokens: ['uidit', 'flammifera', 'confectas', 'nocte', 'latinas', '.']
# subword tokens: ['<s>', 'Vidit', 'Ġflamm', 'ifera', 'Ġconf', 'ectas', 'Ġnocte', 'ĠLati', 'nas', '.', '</s>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 3
# word tokens: ['uidit', 'flammifera', 'confectas', 'nocte', 'latinas', '.']
# subword tokens: ['<s>', 'Vidit', 'Ġflamm', 'ifera', 'Ġconf', 'ectas', 'Ġnocte', 'ĠLati', 'nas', '.', '</s>', '<pad>', '<pad>']
# w1_subword_idx: [2, 3]
# w2_subword_idx: [6]
# Given bigram: ['flammifera', 'nocte'], found words: flammifera and nocte
# refs: ['valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6', 'valerius flaccus 1.7']
# word tokens
# 0 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# 1 ['ausa', 'sequi', 'mediosque', 'inter', 'iuga', 'concita', 'cursus']
# 2 ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# 3 ['phoebe', ',', 'mone', ',', 'si', 'cumaeae', 'mihi', 'conscia', 'uatis']
# 4 ['stat', 'casta', 'cortina', 'domo', ',', 'si', 'laurea', 'digna']
# 5 ['fronte', 'uiret', ',', 'tuque', 'o', 'pelagi', 'cui', 'maior', 'aperti']
# w1_line_idx, w1_idx: 2 1
# word tokens: ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# subword tokens: ['<s>', 'rump', 'ere', 'Ġflamm', 'ifer', 'o', 'Ġtandem', 'Ġconsedit', 'ĠOlympo', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 4
# word tokens: ['rumpere', 'flammifero', 'tandem', 'consedit', 'olympo', '.']
# subword tokens: ['<s>', 'rump', 'ere', 'Ġflamm', 'ifer', 'o', 'Ġtandem', 'Ġconsedit', 'ĠOlympo', '.', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [3, 4, 5]
# w2_subword_idx: [8]
# Given bigram: ['flammifero', 'olympo'], found words: flammifero and olympo
# refs: ['ov. met. 2.152', 'ov. met. 2.153', 'ov. met. 2.154', 'ov. met. 2.155', 'ov. met. 2.156', 'ov. met. 2.157']
# word tokens
# 0 ['gaudet', 'et', 'inuito', 'grates', 'agit', 'inde', 'parenti', '.']
# 1 ['interea', 'uolucres', 'pyrois', 'et', 'eous', 'et', 'aethon', ',']
# 2 ['solis', 'equi', ',', 'quartusque', 'phlegon', ',', 'hinnitibus', 'auras']
# 3 ['flammiferis', 'implent', 'pedibusque', 'repagula', 'pulsant', '.']
# 4 ['quae', 'postquam', 'tethys', ',', 'fatorum', 'ignara', 'nepotis']
# 5 ['reppulit', ',', 'et', 'facta', 'est', 'inmensi', 'copia', 'caeli', ',']
# w1_line_idx, w1_idx: 2 7
# word tokens: ['solis', 'equi', ',', 'quartusque', 'phlegon', ',', 'hinnitibus', 'auras']
# subword tokens: ['<s>', 'S', 'olis', 'Ġequi', ',', 'Ġquartus', 'que', 'ĠPhleg', 'on', ',', 'Ġhinn', 'itibus', 'Ġauras', '</s>']
# w2_line_idx, w2_idx: 3 0
# word tokens: ['flammiferis', 'implent', 'pedibusque', 'repagula', 'pulsant', '.']
# subword tokens: ['<s>', 'fl', 'amm', 'if', 'eris', 'Ġimplent', 'Ġpedibusque', 'Ġrepag', 'ula', 'Ġpuls', 'ant', '.', '</s>', '<pad>']
# w1_subword_idx: [12]
# w2_subword_idx: [1, 2, 3, 4]
# Given bigram: ['auras', 'flammiferis'], found words: auras and flammiferis
# refs: ['valerius flaccus 1.2', 'valerius flaccus 1.3', 'valerius flaccus 1.4', 'valerius flaccus 1.5', 'valerius flaccus 1.6', 'valerius flaccus 1.7']
# word tokens
# 0 ['fatidicamque', 'ratem', ',', 'scythici', 'quae', 'phasidis', 'oras']
# ...
# word tokens: ['hic', 'geminae', 'aeternum', 'portae', ',', 'quarum', 'altera', 'dura']
# subword tokens: ['<s>', 'hic', 'Ġgeminae', 'Ġaeternum', 'Ġportae', ',', 'Ġquarum', 'Ġaltera', 'Ġdura', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 3
# word tokens: ['hic', 'geminae', 'aeternum', 'portae', ',', 'quarum', 'altera', 'dura']
# subword tokens: ['<s>', 'hic', 'Ġgeminae', 'Ġaeternum', 'Ġportae', ',', 'Ġquarum', 'Ġaltera', 'Ġdura', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [3]
# w2_subword_idx: [4]
# Given bigram: ['aeternum', 'portae'], found words: aeternum and portae
# refs: ['verg. aen. 6.399', 'verg. aen. 6.400', 'verg. aen. 6.401', 'verg. aen. 6.402', 'verg. aen. 6.403', 'verg. aen. 6.404']
# word tokens
# 0 ['"', 'nullae', 'hic', 'insidiae', 'tales', ';', 'absiste', 'moueri', ';']
# 1 ['nec', 'uim', 'tela', 'ferunt', ';', 'licet', 'ingens', 'ianitor', 'antro']
# 2 ['aeternum', 'latrans', 'exsanguis', 'terreat', 'umbras', ',']
# 3 ['casta', 'licet', 'patrui', 'seruet', 'proserpina', 'limen', '.']
# 4 ['troius', 'aeneas', ',', 'pietate', 'insignis', 'et', 'armis', ',']
# 5 ['ad', 'genitorem', 'imas', 'erebi', 'descendit', 'ad', 'umbras', '.']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['aeternum', 'latrans', 'exsanguis', 'terreat', 'umbras', ',']
# subword tokens: ['<s>', 'ae', 'ter', 'num', 'Ġlatr', 'ans', 'Ġexs', 'anguis', 'Ġterreat', 'Ġumbras', ',', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 1
# word tokens: ['aeternum', 'latrans', 'exsanguis', 'terreat', 'umbras', ',']
# subword tokens: ['<s>', 'ae', 'ter', 'num', 'Ġlatr', 'ans', 'Ġexs', 'anguis', 'Ġterreat', 'Ġumbras', ',', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1, 2, 3]
# w2_subword_idx: [4, 5]
# Given bigram: ['aeternum', 'latrans'], found words: aeternum and latrans
# refs: ['valerius flaccus 1.832', 'valerius flaccus 1.833', 'valerius flaccus 1.834', 'valerius flaccus 1.835', 'valerius flaccus 1.836', 'valerius flaccus 1.837']
# word tokens
# 0 ['hic', 'geminae', 'aeternum', 'portae', ',', 'quarum', 'altera', 'dura']
# 1 ['semper', 'lege', 'patens', 'populos', 'regesque', 'receptat', ',']
# 2 ['ast', 'aliam', 'temptare', 'nefas', 'et', 'tendere', 'contra', ':']
# 3 ['rara', 'et', 'sponte', 'patet', ',', 'siquando', 'pectore', 'ductor']
# 4 ['uulnera', 'nota', 'gerens', ',', 'galeis', 'praefixa', 'rotisque']
# 5 ['cui', 'domus', 'aut', 'studium', 'mortales', 'pellere', 'curas', ',']
# w1_line_idx, w1_idx: 2 5
# word tokens: ['ast', 'aliam', 'temptare', 'nefas', 'et', 'tendere', 'contra', ':']
# subword tokens: ['<s>', 'ast', 'Ġaliam', 'Ġtemptare', 'Ġnefas', 'Ġet', 'Ġtendere', 'Ġcontra', ':', '</s>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 6
# word tokens: ['ast', 'aliam', 'temptare', 'nefas', 'et', 'tendere', 'contra', ':']
# subword tokens: ['<s>', 'ast', 'Ġaliam', 'Ġtemptare', 'Ġnefas', 'Ġet', 'Ġtendere', 'Ġcontra', ':', '</s>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [6]
# w2_subword_idx: [7]
# Given bigram: ['tendere', 'contra'], found words: tendere and contra
# refs: ['verg. aen. 5.19', 'verg. aen. 5.20', 'verg. aen. 5.21', 'verg. aen. 5.22', 'verg. aen. 5.23', 'verg. aen. 5.24']
# word tokens
# 0 ['mutati', 'transuersa', 'fremunt', 'et', 'uespere', 'ab', 'atro']
# 1 ['consurgunt', 'uenti', ',', 'atque', 'in', 'nubem', 'cogitur', 'ar', '.']
# 2 ['nec', 'nos', 'obniti', 'contra', ',', 'nec', 'tendere', 'tantum']
# 3 ['sufficimus', '.', 'superat', 'quoniam', 'fortuna', ',', 'sequamur', ',']
# 4 ['quoque', 'uocat', ',', 'uertamus', 'iter', '.', 'nec', 'litora', 'longe']
# 5 ['fida', 'reor', 'fraterna', 'erycis', 'portusque', 'sicanos', ',']
# w1_line_idx, w1_idx: 2 6
# word tokens: ['nec', 'nos', 'obniti', 'contra', ',', 'nec', 'tendere', 'tantum']
# subword tokens: ['<s>', 'Nec', 'Ġnos', 'Ġobn', 'iti', 'Ġcontra', ',', 'Ġnec', 'Ġtendere', 'Ġtantum', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 3
# word tokens: ['nec', 'nos', 'obniti', 'contra', ',', 'nec', 'tendere', 'tantum']
# subword tokens: ['<s>', 'Nec', 'Ġnos', 'Ġobn', 'iti', 'Ġcontra', ',', 'Ġnec', 'Ġtendere', 'Ġtantum', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [8]
# w2_subword_idx: [5]
# Given bigram: ['tendere', 'contra'], found words: tendere and contra
# refs: ['valerius flaccus 1.834', 'valerius flaccus 1.835', 'valerius flaccus 1.836', 'valerius flaccus 1.837', 'valerius flaccus 1.838', 'valerius flaccus 1.839']
# word tokens
# 0 ['ast', 'aliam', 'temptare', 'nefas', 'et', 'tendere', 'contra', ':']
# 1 ['rara', 'et', 'sponte', 'patet', ',', 'siquando', 'pectore', 'ductor']
# 2 ['uulnera', 'nota', 'gerens', ',', 'galeis', 'praefixa', 'rotisque']
# 3 ['cui', 'domus', 'aut', 'studium', 'mortales', 'pellere', 'curas', ',']
# 4 ['culta', 'fides', ',', 'longe', 'metus', 'atque', 'ignota', 'cupido', ',']
# 5 ['seu', 'uenit', 'in', 'uittis', 'castaque', 'in', 'ueste', 'sacerdos', '.']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['uulnera', 'nota', 'gerens', ',', 'galeis', 'praefixa', 'rotisque']
# subword tokens: ['<s>', 'v', 'ul', 'nera', 'Ġnota', 'Ġgerens', ',', 'Ġgaleis', 'Ġpraefixa', 'Ġrotis', 'que', '</s>', '<pad>']
# w2_line_idx, w2_idx: 2 2
# word tokens: ['uulnera', 'nota', 'gerens', ',', 'galeis', 'praefixa', 'rotisque']
# subword tokens: ['<s>', 'v', 'ul', 'nera', 'Ġnota', 'Ġgerens', ',', 'Ġgaleis', 'Ġpraefixa', 'Ġrotis', 'que', '</s>', '<pad>']
# w1_subword_idx: [1, 2, 3]
# w2_subword_idx: [5]
# Given bigram: ['uulnera', 'gerens'], found words: uulnera and gerens
# refs: ['verg. aen. 2.276', 'verg. aen. 2.277', 'verg. aen. 2.278', 'verg. aen. 2.279', 'verg. aen. 2.280', 'verg. aen. 2.281']
# word tokens
# 0 ['uel', 'danaum', 'phrygios', 'iaculatus', 'puppibus', 'ignis', ',']
# 1 ['squalentem', 'barbam', 'et', 'concretos', 'sanguine', 'crinis']
# 2 ['uolneraque', 'illa', 'gerens', ',', 'quae', 'circum', 'plurima', 'muros']
# 3 ['accepit', 'patrios', '.', '', 'ultro', 'flens', 'ipse', 'uidebar']
# 4 ['compellare', 'uirum', 'et', 'maestas', 'expromere', 'uoces', ':']
# 5 ['"', 'o', 'lux', 'dardaniae', ',', 'spes', 'o', 'fidissima', 'teucrum', ',']
# w1_line_idx, w1_idx: 2 0
# word tokens: ['uolneraque', 'illa', 'gerens', ',', 'quae', 'circum', 'plurima', 'muros']
# subword tokens: ['<s>', 'vol', 'n', 'eraque', 'Ġilla', 'Ġgerens', ',', 'Ġquae', 'Ġcircum', 'Ġplurima', 'Ġmuros', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 2
# word tokens: ['uolneraque', 'illa', 'gerens', ',', 'quae', 'circum', 'plurima', 'muros']
# subword tokens: ['<s>', 'vol', 'n', 'eraque', 'Ġilla', 'Ġgerens', ',', 'Ġquae', 'Ġcircum', 'Ġplurima', 'Ġmuros', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [1, 2, 3]
# w2_subword_idx: [5]
# Given bigram: ['uolneraque', 'gerens'], found words: uolneraque and gerens
# refs: ['valerius flaccus 1.837', 'valerius flaccus 1.838', 'valerius flaccus 1.839', 'valerius flaccus 1.840', 'valerius flaccus 1.841', 'valerius flaccus 1.842']
# word tokens
# 0 ['cui', 'domus', 'aut', 'studium', 'mortales', 'pellere', 'curas', ',']
# 1 ['culta', 'fides', ',', 'longe', 'metus', 'atque', 'ignota', 'cupido', ',']
# 2 ['seu', 'uenit', 'in', 'uittis', 'castaque', 'in', 'ueste', 'sacerdos', '.']
# 3 ['quos', 'omnes', 'leuibus', 'plantis', 'et', 'lampada', 'quassans']
# 4 ['progenies', 'atlantis', 'agit', '.', 'lucet', 'uia', 'late']
# 5 ['igne', 'dei', ',', 'donec', 'siluas', 'et', 'amoena', 'piorum']
#   set alt w1 from uitta to uittis
#   set alt w2 from sacerdo to sacerdos
# w1_line_idx, w1_idx: 2 3
# word tokens: ['seu', 'uenit', 'in', 'uittis', 'castaque', 'in', 'ueste', 'sacerdos', '.']
# subword tokens: ['<s>', 'seu', 'Ġvenit', 'Ġin', 'Ġvit', 'tis', 'Ġcas', 'taque', 'Ġin', 'Ġveste', 'Ġsacerdos', '.', '</s>']
# w2_line_idx, w2_idx: 2 7
# word tokens: ['seu', 'uenit', 'in', 'uittis', 'castaque', 'in', 'ueste', 'sacerdos', '.']
# subword tokens: ['<s>', 'seu', 'Ġvenit', 'Ġin', 'Ġvit', 'tis', 'Ġcas', 'taque', 'Ġin', 'Ġveste', 'Ġsacerdos', '.', '</s>']
# w1_subword_idx: [4, 5]
# w2_subword_idx: [10]
# Given bigram: ['uitta', 'sacerdo'], found words: uittis and sacerdos
# refs: ['ov. met. 15.673', 'ov. met. 15.674', 'ov. met. 15.675', 'ov. met. 15.676', 'ov. met. 15.677', 'ov. met. 15.678']
# word tokens
# 0 ['pectoribusque', 'tenus', 'media', 'sublimis', 'in', 'aede']
# 1 ['constitit', 'atque', 'oculos', 'circumtulit', 'igne', 'micantes', '.']
# 2 ['territa', 'turba', 'pauet', '.', 'cognouit', 'numina', 'castos']
# 3 ['euinctus', 'uitta', 'crines', 'albente', 'sacerdos', ':']
# 4 ['"', 'en', 'deus', 'est', 'deus', 'est', '!', 'animis', 'linguisque', 'fauete', ',']
# 5 ['quisquis', 'ades', '!"', 'dixit', '.', '"', 'sis', ',', 'o', 'pulcherrime', ',', 'uisus']
# w1_line_idx, w1_idx: 3 1
# word tokens: ['euinctus', 'uitta', 'crines', 'albente', 'sacerdos', ':']
# subword tokens: ['<s>', 'ev', 'inctus', 'Ġvit', 'ta', 'Ġcrines', 'Ġalb', 'ente', 'Ġsacerdos', ':', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 3 4
# word tokens: ['euinctus', 'uitta', 'crines', 'albente', 'sacerdos', ':']
# subword tokens: ['<s>', 'ev', 'inctus', 'Ġvit', 'ta', 'Ġcrines', 'Ġalb', 'ente', 'Ġsacerdos', ':', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [3, 4]
# w2_subword_idx: [8]
# Given bigram: ['uitta', 'sacerdos'], found words: uitta and sacerdos
# refs: ['valerius flaccus 1.837', 'valerius flaccus 1.838', 'valerius flaccus 1.839', 'valerius flaccus 1.840', 'valerius flaccus 1.841', 'valerius flaccus 1.842']
# word tokens
# 0 ['cui', 'domus', 'aut', 'studium', 'mortales', 'pellere', 'curas', ',']
# 1 ['culta', 'fides', ',', 'longe', 'metus', 'atque', 'ignota', 'cupido', ',']
# 2 ['seu', 'uenit', 'in', 'uittis', 'castaque', 'in', 'ueste', 'sacerdos', '.']
# 3 ['quos', 'omnes', 'leuibus', 'plantis', 'et', 'lampada', 'quassans']
# 4 ['progenies', 'atlantis', 'agit', '.', 'lucet', 'uia', 'late']
# 5 ['igne', 'dei', ',', 'donec', 'siluas', 'et', 'amoena', 'piorum']
# w1_line_idx, w1_idx: 2 4
# word tokens: ['seu', 'uenit', 'in', 'uittis', 'castaque', 'in', 'ueste', 'sacerdos', '.']
# subword tokens: ['<s>', 'seu', 'Ġvenit', 'Ġin', 'Ġvit', 'tis', 'Ġcas', 'taque', 'Ġin', 'Ġveste', 'Ġsacerdos', '.', '</s>']
# w2_line_idx, w2_idx: 2 7
# word tokens: ['seu', 'uenit', 'in', 'uittis', 'castaque', 'in', 'ueste', 'sacerdos', '.']
# subword tokens: ['<s>', 'seu', 'Ġvenit', 'Ġin', 'Ġvit', 'tis', 'Ġcas', 'taque', 'Ġin', 'Ġveste', 'Ġsacerdos', '.', '</s>']
# w1_subword_idx: [6, 7]
# w2_subword_idx: [10]
# Given bigram: ['castaque', 'sacerdos'], found words: castaque and sacerdos
# refs: ['verg. aen. 6.659', 'verg. aen. 6.660', 'verg. aen. 6.661', 'verg. aen. 6.662', 'verg. aen. 6.663', 'verg. aen. 6.664']
# word tokens
# 0 ['plurimus', 'eridani', 'per', 'siluam', 'uoluitur', 'amnis', '.']
# 1 ['hic', 'manus', 'ob', 'patriam', 'pugnando', 'uolnera', 'passi', ',']
# 2 ['quique', 'sacerdotes', 'casti', ',', 'dum', 'uita', 'manebat', ',']
# 3 ['quique', 'pii', 'uates', 'et', 'phoebo', 'digna', 'locuti', ',']
# 4 ['inuentas', 'aut', 'qui', 'uitam', 'excoluere', 'per', 'artes', ',']
# 5 ['quique', 'sui', 'memores', 'alios', 'fecere', 'merendo', ',']
# w1_line_idx, w1_idx: 2 1
# word tokens: ['quique', 'sacerdotes', 'casti', ',', 'dum', 'uita', 'manebat', ',']
# subword tokens: ['<s>', 'qui', 'que', 'Ġsacerdotes', 'Ġcasti', ',', 'Ġdum', 'Ġvita', 'Ġmanebat', ',', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 2
# word tokens: ['quique', 'sacerdotes', 'casti', ',', 'dum', 'uita', 'manebat', ',']
# subword tokens: ['<s>', 'qui', 'que', 'Ġsacerdotes', 'Ġcasti', ',', 'Ġdum', 'Ġvita', 'Ġmanebat', ',', '</s>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [3]
# w2_subword_idx: [4]
# Given bigram: ['sacerdotes', 'casti'], found words: sacerdotes and casti
# refs: ['valerius flaccus 1.839', 'valerius flaccus 1.840', 'valerius flaccus 1.841', 'valerius flaccus 1.842', 'valerius flaccus 1.843', 'valerius flaccus 1.844']
# word tokens
# 0 ['seu', 'uenit', 'in', 'uittis', 'castaque', 'in', 'ueste', 'sacerdos', '.']
# 1 ['quos', 'omnes', 'leuibus', 'plantis', 'et', 'lampada', 'quassans']
# 2 ['progenies', 'atlantis', 'agit', '.', 'lucet', 'uia', 'late']
# 3 ['igne', 'dei', ',', 'donec', 'siluas', 'et', 'amoena', 'piorum']
# 4 ['deueniant', 'camposque', ',', 'ubi', 'sol', 'totumque', 'per', 'annum']
# 5 ['durat', 'aprica', 'dies', 'thiasique', 'chorique', 'uirorum']
# w1_line_idx, w1_idx: 2 4
# word tokens: ['progenies', 'atlantis', 'agit', '.', 'lucet', 'uia', 'late']
# subword tokens: ['<s>', 'p', 'rog', 'eni', 'es', 'ĠAtl', 'antis', 'Ġagit', '.', 'Ġlucet', 'Ġvia', 'Ġlate', '</s>']
# w2_line_idx, w2_idx: 2 5
# word tokens: ['progenies', 'atlantis', 'agit', '.', 'lucet', 'uia', 'late']
# subword tokens: ['<s>', 'p', 'rog', 'eni', 'es', 'ĠAtl', 'antis', 'Ġagit', '.', 'Ġlucet', 'Ġvia', 'Ġlate', '</s>']
# w1_subword_idx: [9]
# w2_subword_idx: [10]
# Given bigram: ['lucet', 'uia'], found words: lucet and uia
# refs: ['verg. aen. 11.141', 'verg. aen. 11.142', 'verg. aen. 11.143', 'verg. aen. 11.144', 'verg. aen. 11.145', 'verg. aen. 11.146']
# word tokens
# 0 ['quae', 'modo', 'uictorem', 'latio', 'pallanta', 'ferebat', '.']
# 1 ['arcades', 'ad', 'portas', 'ruere', 'et', 'de', 'more', 'uetusto']
# 2 ['funereas', 'rapuere', 'faces', ';', 'lucet', 'uia', 'longo']
# 3 ['ordine', 'flammarum', 'et', 'late', 'discriminat', 'agros', '.']
# 4 ['contra', 'turba', 'phrygum', 'ueniens', 'plangentia', 'iungit']
# 5 ['agmina', '.', 'quae', 'postquam', 'matres', 'succedere', 'tectis']
# w1_line_idx, w1_idx: 2 4
# word tokens: ['funereas', 'rapuere', 'faces', ';', 'lucet', 'uia', 'longo']
# subword tokens: ['<s>', 'f', 'un', 'ere', 'as', 'Ġrap', 'uere', 'Ġfaces', ';', 'Ġlucet', 'Ġvia', 'Ġlongo', '</s>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 5
# word tokens: ['funereas', 'rapuere', 'faces', ';', 'lucet', 'uia', 'longo']
# subword tokens: ['<s>', 'f', 'un', 'ere', 'as', 'Ġrap', 'uere', 'Ġfaces', ';', 'Ġlucet', 'Ġvia', 'Ġlongo', '</s>', '<pad>', '<pad>']
# w1_subword_idx: [9]
# w2_subword_idx: [10]
# Given bigram: ['lucet', 'uia'], found words: lucet and uia
# refs: ['valerius flaccus 1.847', 'valerius flaccus 1.848', 'valerius flaccus 1.849', 'valerius flaccus 1.850']
# word tokens
# 0 ['inducitque', 'nurum', '.', 'tum', 'porta', 'quanta', 'sinistra']
# 1 ['poena', 'docet', 'maneat', 'pelian', ',', 'quot', 'limine', 'monstra', '.']
# 2 ['mirantur', 'tantos', 'strepitus', 'turbamque', 'ruentem']
# 3 ['et', 'loca', 'et', 'infernos', 'almae', 'uirtutis', 'honores', '.']
# w1_line_idx, w1_idx: 2 3
# word tokens: ['mirantur', 'tantos', 'strepitus', 'turbamque', 'ruentem']
# subword tokens: ['<s>', 'mir', 'antur', 'Ġtantos', 'Ġstrepitus', 'Ġturb', 'amque', 'Ġru', 'entem', '</s>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 4
# word tokens: ['mirantur', 'tantos', 'strepitus', 'turbamque', 'ruentem']
# subword tokens: ['<s>', 'mir', 'antur', 'Ġtantos', 'Ġstrepitus', 'Ġturb', 'amque', 'Ġru', 'entem', '</s>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [5, 6]
# w2_subword_idx: [7, 8]
# Given bigram: ['turbamque', 'ruentem'], found words: turbamque and ruentem
# refs: ['verg. aen. 6.303', 'verg. aen. 6.304', 'verg. aen. 6.305', 'verg. aen. 6.306', 'verg. aen. 6.307', 'verg. aen. 6.308']
# word tokens
# 0 ['et', 'ferruginea', 'subuectat', 'corpora', 'cymba', ',']
# 1 ['iam', 'senior', ',', 'sed', 'cruda', 'deo', 'uiridisque', 'senectus', '.']
# 2 ['huc', 'omnis', 'turba', 'ad', 'ripas', 'effusa', 'ruebat', ',']
# 3 ['matres', 'atque', 'uiri', ',', 'defunctaque', 'corpora', 'uita']
# 4 ['magnanimum', 'heroum', ',', 'pueri', 'innuptaeque', 'puellae', ',']
# 5 ['impositique', 'rogis', 'iuuenes', 'ante', 'ora', 'parentum', ':']
# w1_line_idx, w1_idx: 2 2
# word tokens: ['huc', 'omnis', 'turba', 'ad', 'ripas', 'effusa', 'ruebat', ',']
# subword tokens: ['<s>', 'Huc', 'Ġomnis', 'Ġturba', 'Ġad', 'Ġripas', 'Ġeffusa', 'Ġru', 'ebat', ',', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w2_line_idx, w2_idx: 2 6
# word tokens: ['huc', 'omnis', 'turba', 'ad', 'ripas', 'effusa', 'ruebat', ',']
# subword tokens: ['<s>', 'Huc', 'Ġomnis', 'Ġturba', 'Ġad', 'Ġripas', 'Ġeffusa', 'Ġru', 'ebat', ',', '</s>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']
# w1_subword_idx: [3]
# w2_subword_idx: [7, 8]
# Given bigram: ['turba', 'ruebat'], found words: turba and ruebat

# %%
len(bert_pairs)
# Out:
# 944

# %%
row = comps.iloc[0]
row
# Out:
# VF: Line Start                                                           1
# VF: Line End                                                             1
# VF: Lemma                                                    prima canimus
# Intertext: Author                                                   Vergil
# Intertext: Work                                                     Aeneid
# Intertext: Book                                                          1
# Intertext: Line Start                                                    1
# Intertext: Line End                                                      1
# Kleywegt Ref.                                                          6.0
# Zissos Ref.                                                           74.0
# Spaltenstein Ref.                                                     23.0
# Intertext: Phrase                                              cano primus
# Query Phrase                                                 prima canimus
# Result Phrase                                                  cano primus
# Order Free                                                            True
# Interval                                                               2.0
# query_length                                                             2
# result_length                                                            2
# ref                                                      Vergil Aeneid 1.1
# index                                                     <verg. aen. 1.1>
# file                                             vergil.aeneid.part.1.tess
# intertext_author                                                    vergil
# intertext_book                                                           1
# Query                                                        prima canimus
# Result                                                         cano primus
# orderfree                                                             True
# interval                                                               2.0
# query_lemma                                                    primus cano
# target_lemma                                                   cano primus
# pairs                    (('primus', 'cano'), ('primus', 'primus'), ('c...
# similarities                            [0.26957032, 1.0, 1.0, 0.26957032]
# similarity                                                             1.0
# Name: 0, dtype: object

# %%
query_pos[0], query_morph[0]
# Out:
# (('ADJ', 'NOUN'),
#  ({'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing'},
#   {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'}))

# %%
bert_query[0], bert_query_indices[0]
# Out:
# ('prima canimus', ((0, 1), (3, 1)))

# %%
# add to dataframe
comps['bert_query'] = bert_query
comps['bert_result'] = bert_result
comps['bert_query_indices'] = bert_query_indices
comps['bert_result_indices'] = bert_result_indices
comps['bert_pairs'] = bert_pairs
comps['bert_similarities'] = bert_similarities
comps['bert_similarity'] = bert_similarity
comps['query_pos'] = query_pos
comps['query_morph'] = query_morph
comps['result_pos'] = result_pos
comps['result_morph'] = result_morph

comps.to_csv('../data/datasets/comps_bert_pos.csv')

# %%
aeneid_data = EMBEDDINGS_FOLDER + '/vergil.aeneid.part.1.tess.pos.pkl'
aeneid_data = load_data(aeneid_data)
aeneid_data = sort_data(aeneid_data)

# %%
aeneid_data['verg. aen. 1.1']['word_tokens']
# Out:
# ['Arma', 'virumque', 'cano', ',', 'Troiae', 'qui', 'primus', 'ab', 'oris']

# %%
aeneid_data['verg. aen. 1.1']['pos_tags']
# Out:
# ['NOUN', 'NOUN', 'ADJ', 'PUNCT', 'PROPN', 'PRON', 'ADJ', 'ADP', 'NOUN']

# %% [markdown]
# intertext search over all possible bigrams (no pos constraints)

# %%
from tqdm import tqdm
from cltk.lemmatize.lat import LatinBackoffLemmatizer as BackoffLatinLemmatizer
lemmatizer = BackoffLatinLemmatizer()

# %%
lemmatize = False

# %%
comps = pd.read_csv('../data/datasets/comps_bert.csv', index_col=0)
comps['bert_query'] = comps['bert_query'].apply(lambda x: x.split() if not pd.isna(x) else [])
comps['bert_result'] = comps['bert_result'].apply(lambda x: x.split() if not pd.isna(x) else [])

# %%
# Text functions

def preprocess(text):
    replacer = JVReplacer()    
    text = text.lower()
    text = replacer.replace(text) #Normalize u/v & i/j
    
    text = text.replace('ego---sed', 'egosed') # handle a tesserae text issue
    
    punctuation ="\"#$%&\'()*+,-/:;<=>@[\]^_`{|}~.?!«»"
    translator = str.maketrans({key: " " for key in punctuation})
    text = text.translate(translator)

    translator = str.maketrans({key: " " for key in '0123456789'})
    text = text.translate(translator)
    
    text = text.replace('â\x80\x94', ' ')
    
    text = " ".join(text.split())
    
    return text

def index_tess(text):
    
    textlines = text.strip().split('\n')
    # https://stackoverflow.com/a/61436083
    def splitkeep(s, delimiter):
        split = s.split(delimiter)
        return [substr + delimiter for substr in split[:-1]] + [split[-1]]
    textlines = [splitkeep(line, '>') for line in textlines if line]
    return dict(textlines)

def pp_tess(tess_dict):
    return {k: preprocess(v) for k, v in tess_dict.items()}

def text_lemmatize(lemma_pairs):
    return " ".join([lemma for _, lemma in lemma_pairs])

def lem_tess(tess_dict):
    return {k: text_lemmatize(lemmatizer.lemmatize(v.split())) for k, v in tess_dict.items()}

def make_tess_file(str):
    str = str.lower()
    str = str.replace('lucan', 'lucan bellum_civile')
    str = str.split('.')[0]
    str = str.replace(' ', '.', 1)
    str = str.replace(' ', '.part.', 1)
    str += '.tess'
    return str

def make_tess_index(str):
    str = str.replace('Lucan', 'luc.').replace('Ovid', 'ov.').replace('Statius', 'stat.').replace('Vergil', 'verg.')
    str = str.replace('Metamorphoses', 'met.').replace('Thebaid', 'theb.').replace('Aeneid', 'aen.')
    str = str.split('-')[0]
    str = f'<{str}>'
    return str
'''
def get_next_tess_index(index, n):
    index = index.replace('>','')
    index_base = index.split()[:-1]
    index_ref = index.split()[-1]
    index_ref_parts = index_ref.split('.')
    index_ref_next = int(index_ref_parts[1])+n
    next_index = f'{" ".join(index_base)} {index_ref_parts[0]}.{index_ref_next}>'
    
    exceptions = ['<luc. 1.419>', '<luc. 7.855>', '<luc. 7.856>', '<luc. 7.857>', '<luc. 7.858>', '<luc. 7.859>', '<luc. 7.860>', '<luc. 7.861>', '<luc. 7.862>', '<luc. 7.863>', '<luc. 7.864>', '<luc. 9.414>',
                  '<ov. met. 4.769>', 
                  '<stat. theb. 6.184>', '<stat. theb. 6.227>', '<stat. theb. 6.228>', '<stat. theb. 6.229>', '<stat. theb. 6.230>', '<stat. theb. 6.231>', '<stat. theb. 6.232>', '<stat. theb. 6.233>', '<stat. theb. 9.760>']
    if next_index in exceptions: # Handle missing data
        return None
    else:
        return next_index
'''    
def get_next_tess_index(index, n, data):
    *key_prefix, i = index.split('.')
    key_prefix = '.'.join(key_prefix)
    i = int(i)
    i += n
    
    new_index = f'{key_prefix}.{i}'
    if new_index in data:
        return new_index
    else:
        return None

# %%
# Get ngrams
remove_tokens = ['<s>', '</s>', '<unk>', '<pad>']
punctuation = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

def generate_ngrams(words_list, n):
    # Cf. https://www.techcoil.com/blog/how-to-generate-n-grams-in-python-without-using-any-external-libraries/
    ngrams_list = []

    for num in range(0, len(words_list)):
        ngram = ' '.join(words_list[num:num + n])
        ngrams_list.append(ngram)
    
    ngrams_list = [item.split() for item in ngrams_list if len(item.split()) == n]
    
    return ngrams_list

def generate_ngrams_interval(words_list, index, n, tess_dict, interval):
    valid_indices = []
    for i, token in enumerate(words_list):
        if token not in remove_tokens and token not in punctuation:
            valid_indices.append((i, 0)) # (index, offset from current reference/index)
    
    limit = len(valid_indices) + interval + 1 # add one to avoid interval-based fencepost problem
    
    current_ref = index
    ref_offset = 0
    while len(valid_indices) < limit:
        next_ref = get_next_tess_index(current_ref, 1, tess_dict)
        if next_ref:
            ref_offset += 1
            start_idx = len(words_list)
            next_words = tess_dict[next_ref]['word_tokens']
            words_list.extend(next_words)
            
            # Add new valid indices
            for i, token in enumerate(next_words):
                if token not in remove_tokens and token not in punctuation:
                    valid_indices.append((i, ref_offset))
            current_ref = next_ref
        else:
            break
    valid_indices = valid_indices[:limit]
    
    ngrams_list = []
    for num in range(len(valid_indices) - n + 1):
        ngram_indices = valid_indices[num:num + n]
        if len(ngram_indices) == n:
            ngrams_list.append(ngram_indices)
    
    return ngrams_list

def ngram_tess(tess_dict, n=2, interval=0):
    '''Return ngram indices into the word_tokens list, skipping punctuation'''
    #return {k: generate_ngrams_interval(v.split(), k, n, tess_dict, interval) for k, v in list(tess_dict.items())[:-1]} # Stop short of last item because of ngram lookahead
    ngrams_dict = {}
    for ref, data in tess_dict.items():
        word_tokens = data['word_tokens']
        ngram_indices = generate_ngrams_interval(word_tokens, ref, n, tess_dict, interval)
        
        tokens = []
        for ngram in ngram_indices:
            ngram_tokens = []
            for idx, offset in ngram:
                if offset == 0:
                    token = word_tokens[idx]
                else:
                    next_ref = get_next_tess_index(ref, offset, tess_dict)
                    token = tess_dict[next_ref]['word_tokens'][idx]
                ngram_tokens.append(token)
            tokens.append(ngram_tokens)

        ngrams_dict[ref] = {
            'indices': ngram_indices,
            'tokens': tokens
        }

    return ngrams_dict

# %%
def get_similarities(pairs):
    return [np.dot(p1, p2) / (np.linalg.norm(p1) * np.linalg.norm(p2)) for p1, p2 in pairs]

# %%
search_files = natsorted([file for file in files if row['intertext_author'] in file])
file = search_files[0]

if np.isnan(row['interval']):
    interval = 0
else:
    interval = int(row['interval'])
    
n = row['query_length'] + interval
with open(file, 'r') as f:
    contents = f.read()
    tess_dict = index_tess(contents)    
    tess_dict = pp_tess(tess_dict)
    if lemmatize:
        tess_dict = lem_tess(tess_dict)
tess_dict = ngram_tess(tess_dict, n, interval)

# %%
search_files = natsorted([file for file in files_embeddings if row['intertext_author'] in file])
file = search_files[0]

if np.isnan(row['interval']):
    interval = 0
else:
    interval = int(row['interval'])
    
n = row['query_length'] + interval
tess_data = load_data(file)
tess_data = sort_data(tess_data)
tess_dict_new = ngram_tess(tess_data, n, interval)

# %%
index = 'verg. aen. 1.1'
#ngram_data = tess_dict['<'+index+'>']
ngram_data= tess_dict_new[index]

ngram = ngram_data['indices'][0]
ngram_tokens = ngram_data['tokens'][0]
#ngram = ngram_data['tokens'][0]
#ngram = ngram_data[0]
orderfree = row['orderfree']
if orderfree:
    combs = list(combinations(ngram, 2))
    combs_tokens = list(combinations(ngram_tokens, 2))
else:
    combs = [ngram]
    combs_tokens = [ngram_tokens]

# %%
index = 'valerius flaccus 1.1'
#ngram_data = tess_dict['<'+index+'>']
row = comps.iloc[0]
ngram = eval(row['bert_query_indices'])
ngram_tokens = row['bert_query']

#ngram = ngram_data['indices'][0]
#ngram_tokens = ngram_data['tokens'][0]
#ngram = ngram_data['tokens'][0]
#ngram = ngram_data[0]
orderfree = row['orderfree']
if orderfree:
    combs = list(combinations(ngram, 2))
    combs_tokens = list(combinations(ngram_tokens, 2))
else:
    combs = [ngram]
    combs_tokens = [ngram_tokens]

# %%
eval(row['bert_query_indices'])
# Out:
# ((0, 1), (3, 1))

# %%
combs
# Out:
# [((0, 1), (3, 1))]

# %%
combs_tokens
# Out:
# [('prima', 'canimus')]

# %%
position = combs[0][1]
position
# Out:
# (3, 1)

# %%
position_embedding = get_bert_embeddings(position, new_vf_data, line_is_global=True)
# Out:
# tokens: ['Ġcanimus']
# num embeddings: 1

# %%
len(position_embedding)
# Out:
# 768

# %%
def get_bert_embeddings(indices: tuple[int, int], data: dict, line_is_global: bool = True, ref: str = None):
    '''If line_is_global, then indices are global line numbers, not offsets;
    otherwise, indices are offsets from ref
    
    indices: tuple[int, int], the word and line indices for a single word
    ''' 

    word_idx, line_idx = indices
    if line_is_global:
        first_key = ''
        for key in data:
            first_key = key
            break

        *key_prefix, _ = first_key.split('.')
        key_prefix = '.'.join(key_prefix)
        new_ref = f'{key_prefix}.{line_idx}'
    else:
        offset = line_idx
        *key_prefix, ref_i = ref.split('.')
        key_prefix = '.'.join(key_prefix)
        ref_i = int(ref_i)
        new_ref = f'{key_prefix}.{ref_i + offset}'

    # subword embeddings
    
    word_to_tokens_map = data[new_ref]['word_to_tokens_maps'][word_idx]
    #subword_tokens = [data[new_ref]['subword_tokens'][i] for i in word_to_tokens_map]
    #print('tokens:', subword_tokens)
    embeddings = data[new_ref]['embeddings'][word_to_tokens_map]
    #print('num embeddings:', len(embeddings))
    # average to get word embedding
    word_embedding = np.mean(embeddings, axis=0)
    
    return word_embedding

# %%
tess_data[index].keys()
# Out:
# dict_keys(['references', 'embeddings', 'sentences', 'word_to_tokens_maps', 'subword_tokens', 'word_tokens'])

# %%
# # Uncomment code to run full intertext search over texts

# # Get intertext search results

results_ = []

for i, row in tqdm(comps.iterrows(), total=comps.shape[0]):    

    search_files = natsorted([file for file in files_embeddings if row['intertext_author'] in file])
    
    if np.isnan(row['interval']):
        interval = 0
    else:
        interval = int(row['interval'])
    
    n = row['query_length'] + interval
    
    results = []
    if not row['bert_query']:
        continue

    # query bert embeddings 
    query_indices = eval(row['bert_query_indices'])
    vf_w1_embedding = get_bert_embeddings(query_indices[0], new_vf_data, line_is_global=True)
    vf_w2_embedding = get_bert_embeddings(query_indices[1], new_vf_data, line_is_global=True)
    query_embeddings = (vf_w1_embedding, vf_w2_embedding)
    
    for file in search_files:
        #with open(file, 'r') as f:
        #    contents = f.read()
        #    tess_dict = index_tess(contents)    
        #    tess_dict = pp_tess(tess_dict)
        #    if lemmatize:
        #        tess_dict = lem_tess(tess_dict)
        #tess_dict = ngram_tess(tess_dict, n, interval) 
        
        # open data file
        tess_data = load_data(file)
        tess_data = sort_data(tess_data)

        # generate ngrams
        tess_dict = ngram_tess(tess_data, n, interval)      

        for ref, ngram_data in tess_dict.items():           
            
            for j, ngram in enumerate(ngram_data['indices']): 
                tokens = ngram_data['tokens'][j]            
                orderfree = row['orderfree']
                if orderfree:
                    combs = list(combinations(ngram, 2))
                    combs_tokens = list(combinations(tokens, 2))
                else:
                    combs = [ngram]
                    combs_tokens = [tokens]

                for comb, comb_tokens in zip(combs, combs_tokens):
                    comb_w1_embedding = get_bert_embeddings(comb[0], tess_data, line_is_global=False, ref=ref)
                    comb_w2_embedding = get_bert_embeddings(comb[1], tess_data, line_is_global=False, ref=ref)
                    comb_embedding = (comb_w1_embedding, comb_w2_embedding)

                    #pairs = tuple(product(row["query_bert"], comb))
                    pairs = tuple(product(query_embeddings, comb_embedding))

                    dists = get_similarities(pairs)
                    dists_sum = compute_bigram_similarity(dists)
                    if dists_sum >= row["bert_similarity"]:
                        results.append((ref, dists_sum, row['query_bert'], list(comb_tokens)))
    results_.append((row['index'], results))
# Out:
#   0%|          | 1/944 [00:28<7:24:37, 28.29s/it]Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f7c12243fa0>>
# Traceback (most recent call last):
#   File "/work/pi_brenocon_umass_edu/marisa/poetry_cache/virtualenvs/naacl-hlt-2021-latin-intertextuality-ZPY7aNxM-py3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
#   0%|          | 2/944 [00:47<6:10:25, 23.59s/it]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /work/pi_brenocon_umass_edu/marisa/poetry_cache/virtualenvs/naacl-hlt-2021-latin-intertextuality-ZPY7aNxM-py3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /work/pi_brenocon_umass_edu/marisa/poetry_cache/virtualenvs/naacl-hlt-2021-latin-intertextuality-ZPY7aNxM-py3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /work/pi_brenocon_umass_edu/marisa/poetry_cache/virtualenvs/naacl-hlt-2021-latin-intertextuality-ZPY7aNxM-py3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'query_bert'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[183], line 67
#      65                 dists_sum = compute_bigram_similarity(dists)
#      66                 if dists_sum >= row["similarity"]:
# ---> 67                     results.append((index, dists_sum, row['query_bert'], list(comb_tokens)))
#      68 results_.append((row['index'], results))
#
# File /work/pi_brenocon_umass_edu/marisa/poetry_cache/virtualenvs/naacl-hlt-2021-latin-intertextuality-ZPY7aNxM-py3.9/lib/python3.9/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /work/pi_brenocon_umass_edu/marisa/poetry_cache/virtualenvs/naacl-hlt-2021-latin-intertextuality-ZPY7aNxM-py3.9/lib/python3.9/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File /work/pi_brenocon_umass_edu/marisa/poetry_cache/virtualenvs/naacl-hlt-2021-latin-intertextuality-ZPY7aNxM-py3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'query_bert'

# %%
import pickle
import datetime
import os
from statistics import mean

# %%
output_path = f"{os.path.join('temp', datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S'))}-results.p"
pickle.dump(results_, open(output_path, 'wb'))

# For paper results, uncomment to download and run remaining cells
# url = 'https://utexas.box.com/shared/static/2m2e09dijfxgqg3nnxei2cuttc7qu7kd.p'
# urllib.request.urlretrieve (url, 'temp/results_naacl2021_search.p')

# output_path = 'temp/results_naacl2021_search.p'
# results_ = pickle.load(open(output_path, 'rb'))
print(f'Temp results saved at {output_path}')

# %%
# load results
#result_name = '../notebooks/temp/2024-12-03_19-33-56-start-0-end-10-results.p'
result_name = '../notebooks/temp/2024-11-24_03-32-36-results.p'
results_ = pickle.load(open(result_name, 'rb'))
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
len(results_)
# Out:
# 10

# %%
# Get ranks

ranks = [len(result[1]) for result in results_ if len(result[1]) != 0]

# %%
# Compute recall & precision at k; computer MRR

ks = [1, 3, 5, 10, 25, 50, 75, 100, 250]

def recall_at_k(ranks, k):
    n = len([rank for rank in ranks if rank <= k])
    d = len(ranks)
    recall = n/d
    return recall

def precision_at_k(ranks, k):
    n = len([rank for rank in ranks if rank <= k])
    d = sum([rank if rank<=k else k for rank in ranks])
    precision = n/d
    return precision

def mrr(ranks):
    return mean([1/item for item in ranks])

print(f'MRR: {mrr(ranks)}')
print()

print(f'Checking the following values for k {ks}\n')
for k in ks:
    print(f'\tRecall at k={k}: {recall_at_k(ranks, k)}')
    print(f'\tPrecision at k={k}: {precision_at_k(ranks, k)}')
    print()
# Out:
# MRR: 0.03740907220278302
#
# Checking the following values for k [1, 3, 5, 10, 25, 50, 75, 100, 250]
#
# 	Recall at k=1: 0.0
# 	Precision at k=1: 0.0
#
# 	Recall at k=3: 0.0
# 	Precision at k=3: 0.0
#
# 	Recall at k=5: 0.0
# 	Precision at k=5: 0.0
#
# 	Recall at k=10: 0.0
# 	Precision at k=10: 0.0
#
# 	Recall at k=25: 0.4
# 	Precision at k=25: 0.0196078431372549
#
# 	Recall at k=50: 0.6
# 	Precision at k=50: 0.017964071856287425
#
# 	Recall at k=75: 0.6
# 	Precision at k=75: 0.013824884792626729
#
# 	Recall at k=100: 0.6
# 	Precision at k=100: 0.011235955056179775
#
# 	Recall at k=250: 0.8
# 	Precision at k=250: 0.009237875288683603
